# %% [markdown]
# # Finalised ridership analysis
#
# Removed analysis involving multiple directions (since we decided to only analyse 1 direction for consistency)
# Saved some of the intermediate tables for plotting in the dashboard
# The function `get_hour_count_below_25th_percentile_each_stop` from here is reproduced in the streamlit app code

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
bus_routes = pd.read_json('../data/cleaned/BusRoutes.json', lines=True)
# bus_ridership_quarter = pd.read_csv('../data/cleaned/BusRideVolume_2024_070809.csv', dtype={'PT_CODE': int})
bus_routes_trips = pd.read_csv('../data/cleaned/bus_route_trips.csv')

# %%
bus_routes_trips
# Out:
#        ServiceNo  Direction  Origin_Stop  Destination_Stop  \
# 0            118          1      96289.0           96109.0
# 1            118          1      96289.0           96109.0
# 2            118          1      96289.0           96109.0
# 3            118          1      96289.0           96109.0
# 4            118          1      96289.0           96109.0
# ...          ...        ...          ...               ...
# 713499       992          2      40309.0           43409.0
# 713500       992          2      40309.0           43409.0
# 713501       992          2      40309.0           43409.0
# 713502       992          2      40309.0           43409.0
# 713503       992          2      40309.0           43409.0
#
#         Origin_StopSequence  Destination_StopSequence          DAY_TYPE  \
# 0                      19.0                      20.0           WEEKDAY
# 1                      19.0                      20.0  WEEKENDS/HOLIDAY
# 2                      19.0                      20.0  WEEKENDS/HOLIDAY
# 3                      19.0                      20.0           WEEKDAY
# 4                      19.0                      20.0           WEEKDAY
# ...                     ...                       ...               ...
# 713499                 12.0                      13.0           WEEKDAY
# 713500                 12.0                      13.0           WEEKDAY
# 713501                 12.0                      13.0  WEEKENDS/HOLIDAY
# 713502                 12.0                      13.0  WEEKENDS/HOLIDAY
# 713503                 12.0                      13.0           WEEKDAY
#
#         TIME_PER_HOUR PT_TYPE  TOTAL_TRIPS Category  Max_StopSequence  \
# 0                 8.0     BUS         29.0    TRUNK              26.0
# 1                22.0     BUS          1.0    TRUNK              26.0
# 2                20.0     BUS          7.0    TRUNK              26.0
# 3                11.0     BUS         21.0    TRUNK              26.0
# 4                13.0     BUS         16.0    TRUNK              26.0
# ...               ...     ...          ...      ...               ...
# 713499           13.0     BUS          4.0    TRUNK              15.0
# 713500           17.0     BUS          4.0    TRUNK              15.0
# 713501           10.0     BUS          5.0    TRUNK              15.0
# 713502           16.0     BUS          1.0    TRUNK              15.0
# 713503           12.0     BUS          3.0    TRUNK              15.0
#
#         Adj_Estimated_Trips
# 0                       9.0
# 1                       1.0
# 2                       5.0
# 3                       6.0
# 4                       6.0
# ...                     ...
# 713499                  4.0
# 713500                  4.0
# 713501                  5.0
# 713502                  1.0
# 713503                  3.0
#
# [713504 rows x 13 columns]

# %% [markdown]
# Below filters for trip information to obtain 1 direction only and saves the file, loaded in again 2 cells down

# %%
# bus_routes_trips = bus_routes_trips[bus_routes_trips["Direction"] == 1]
# bus_routes_trips = bus_routes_trips.drop(columns=['Direction'])
# bus_routes_trips.to_csv('../data/cleaned/bus_route_trips_single_direction.csv', index=False)

# %% [markdown]
# Below saves the 3-month averages for each bus stop's ridership for each hour and the day category, next section just loads it in

# %%
# bus_ridership_quarter = bus_ridership_quarter.rename(columns={
#     'PT_CODE':'Destination_Stop'
# })

# aggregated_ridership = bus_ridership_quarter.groupby(['DAY_TYPE', 'TIME_PER_HOUR', 'PT_TYPE', 'Destination_Stop']).agg({
#     'TOTAL_TAP_IN_VOLUME': 'mean',
#     'TOTAL_TAP_OUT_VOLUME': 'mean'
# }).reset_index()

# aggregated_ridership.to_csv('../data/cleaned/aggregated_ridership.csv', index=False)

# ridership_percentiles = aggregated_ridership.groupby(['TIME_PER_HOUR', 'DAY_TYPE']).agg({
#     'TOTAL_TAP_IN_VOLUME': ['mean', lambda x: np.percentile(x, 25), lambda x: np.percentile(x, 75)],
#     'TOTAL_TAP_OUT_VOLUME': ['mean', lambda x: np.percentile(x, 25), lambda x: np.percentile(x, 75)],
# }).reset_index()
# ridership_percentiles.columns = ['TIME_PER_HOUR', 'DAY_TYPE', 'TAP_IN_MEAN', 'TAP_IN_25', 'TAP_IN_75', 'TAP_OUT_MEAN', 'TAP_OUT_25', 'TAP_OUT_75']

# ridership_percentiles.to_csv('../data/cleaned/ridership_percentiles.csv', index=False)

# %%
ridership = pd.read_csv('../data/cleaned/aggregated_ridership.csv')
ridership_percentiles = pd.read_csv('../data/cleaned/ridership_percentiles.csv')
bus_routes_trips = pd.read_csv('../data/cleaned/bus_route_trips_single_direction.csv')

# %%
def get_hour_count_below_25th_percentile_each_stop(bus_service, bus_routes_trips, ridership, ridership_percentiles):
    
    # filter bus_routes_trips to only include the chosen bus service
    chosen_bus_route_trips = bus_routes_trips[bus_routes_trips['ServiceNo'] == bus_service]
    total_num_stops = chosen_bus_route_trips["Max_StopSequence"].max()

    # merge chosen_bus_route_trips with ridership to get the estimated tap in and tap out
    chosen_route_ridership = chosen_bus_route_trips.merge(
        ridership,
        on=['Destination_Stop', 'PT_TYPE', 'TIME_PER_HOUR', 'DAY_TYPE'],
        how='left'
    )

    # calculate the estimated tap in and tap out based on estimated number of trips for the bus route
    chosen_route_ridership['Estimated_Tap_In'] = (chosen_route_ridership['Adj_Estimated_Trips'] *
                                                (chosen_route_ridership['TOTAL_TAP_IN_VOLUME'] / chosen_route_ridership['TOTAL_TRIPS']))
    chosen_route_ridership['Estimated_Tap_Out'] = (chosen_route_ridership['Adj_Estimated_Trips'] *
                                                (chosen_route_ridership['TOTAL_TAP_OUT_VOLUME'] / chosen_route_ridership['TOTAL_TRIPS']))

    # merge chosen_route_ridership with overall ridership_percentiles to get the 25th percentile tap in and tap out
    service_ridership_and_global_ridership = chosen_route_ridership.merge(
        ridership_percentiles,
        on=['TIME_PER_HOUR', 'DAY_TYPE']
    )

    # filter the bus stops to only include those with estimated tap in and tap out below the 25th percentile
    filtered_busstops = service_ridership_and_global_ridership[
        (service_ridership_and_global_ridership['Estimated_Tap_In'] < service_ridership_and_global_ridership['TAP_IN_25']) &
        (service_ridership_and_global_ridership['Estimated_Tap_Out'] < service_ridership_and_global_ridership['TAP_OUT_25']) &
        (service_ridership_and_global_ridership['TIME_PER_HOUR'] > 5) & (service_ridership_and_global_ridership['TIME_PER_HOUR'] < 23)
    ]

    # count the number of hours below the 25th percentile for each service stop
    num_hours_below_25th_by_service_stop = (
        filtered_busstops.groupby(['Destination_StopSequence', 'DAY_TYPE'])
        .size()
        .reset_index(name='Total_Hour_Count')
    )

    # create full index of all possible combinations of Destination_StopSequence and DAY_TYPE
    # this is because some bus stops may not have any hours below the 25th percentile and won't be included in the previous step
    max_sequence = filtered_busstops['Max_StopSequence'].max()
    day_types = filtered_busstops['DAY_TYPE'].unique()
    full_index = pd.MultiIndex.from_product(
        [range(1, int(max_sequence) + 1), day_types], 
        names=['Destination_StopSequence', 'DAY_TYPE']
    )

    # filling missing values with 0
    num_hours_below_25th_by_service_stop = num_hours_below_25th_by_service_stop.set_index(['Destination_StopSequence', 'DAY_TYPE']).reindex(full_index, fill_value=0).reset_index()
    
    return num_hours_below_25th_by_service_stop, total_num_stops

# %% [markdown]
# Run the function for 1 bus route

# %%
hour_count_by_stop_sequence, total_num_stops = get_hour_count_below_25th_percentile_each_stop('167', bus_routes_trips, ridership, ridership_percentiles)
print(f'Total number of stops: {total_num_stops}')
hour_count_by_stop_sequence
# Out:
# Total number of stops: 71.0
#      Destination_StopSequence          DAY_TYPE  Total_Hour_Count
# 0                           1           WEEKDAY                 0
# 1                           1  WEEKENDS/HOLIDAY                 0
# 2                           2           WEEKDAY                 0
# 3                           2  WEEKENDS/HOLIDAY                 0
# 4                           3           WEEKDAY                 0
# ..                        ...               ...               ...
# 137                        69  WEEKENDS/HOLIDAY                 3
# 138                        70           WEEKDAY                 1
# 139                        70  WEEKENDS/HOLIDAY                 1
# 140                        71           WEEKDAY                 1
# 141                        71  WEEKENDS/HOLIDAY                 1
#
# [142 rows x 3 columns]

# %% [markdown]
# Below are functions defined for plotting the data produced above
# We also want to know what proportion of bus stops have a high number of low ridership hours - second function prints it

# %%
# Plotting function for both directions on the same graph
def plot_hour_distribution(hour_counts, threshold, title):
    weekday_data = hour_counts[hour_counts['DAY_TYPE'] == 'WEEKDAY']
    weekend_data = hour_counts[hour_counts['DAY_TYPE'] == 'WEEKENDS/HOLIDAY']

    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 6), sharey=True)
    
    i=0

    axes.scatter(weekday_data['Destination_StopSequence'], weekday_data['Total_Hour_Count'], label=f"Weekday", marker='o')
    axes.scatter(weekend_data['Destination_StopSequence'], weekend_data['Total_Hour_Count'], label=f"Weekend", marker='o')

    axes.axhline(y=threshold, color='r', linestyle='-', label='Threshold')
    
    # Adding labels and title
    axes.set_xlabel("Bus Stop Sequence")
    axes.set_ylabel("Total Hour Count (Occurrences of 0-23)")
    axes.set_title(title)
    axes.legend()
    axes.grid(True)
    
    plt.tight_layout()
    plt.show()

def print_percentage_exceeding_threshold(hour_counts, total_num_stops, threshold):
    # Calculate total sequences and sequences exceeding threshold for each direction
    weekday_data = hour_counts[hour_counts['DAY_TYPE'] == 'WEEKDAY']
    num_hours_low_ridership_weekday = weekday_data.shape[0]
    exceeding_sequences_weekday = weekday_data[weekday_data['Total_Hour_Count'] > threshold].shape[0]
    percentage_exceed_weekday = (exceeding_sequences_weekday / total_num_stops) * 100 if num_hours_low_ridership_weekday else 0
    print(f"Percentage of stop sequences exceeding {threshold} (weekday): {percentage_exceed_weekday:.2f}%")
    
    
    weekend_data = hour_counts[hour_counts['DAY_TYPE'] == 'WEEKENDS/HOLIDAY']
    num_hours_low_ridership_weekend = weekend_data.shape[0]
    exceeding_sequences_weekend = weekend_data[weekend_data['Total_Hour_Count'] > threshold].shape[0]
    percentage_exceed_weekend = (exceeding_sequences_weekend / total_num_stops) * 100 if num_hours_low_ridership_weekend else 0
    print(f"Percentage of stop sequences exceeding {threshold} (weekend): {percentage_exceed_weekend:.2f}%")

# %%
threshold = 6

plot_hour_distribution(hour_count_by_stop_sequence, 
                       6, 
                       "Number of hours of low ridership for each bus stop sequence (threshold = 6 hours)")
print_percentage_exceeding_threshold(hour_count_by_stop_sequence, total_num_stops, threshold)
# Out:
# Percentage of stop sequences exceeding 6 (weekday): 39.44%
# Percentage of stop sequences exceeding 6 (weekend): 14.08%

# %% [markdown]
# Apply function across all bus routes

# %%
# Examine bus_route_trips_data
bus_routes_trips.head(5)

# Drop any na values
bus_routes_trips = bus_routes_trips.dropna()

# %%
# Create a list of all unique serviceNo in the dataset
unique_services = bus_routes_trips['ServiceNo'].unique()
print(len(unique_services))
# Out:
# 556

# %%
# Create custom function to iterate through all bus routes
def percentage_exceeding_threshold(hour_counts, total_num_stops, threshold):
    # Calculate total sequences and sequences exceeding threshold for each direction
    weekday_data = hour_counts[hour_counts['DAY_TYPE'] == 'WEEKDAY']
    num_hours_low_ridership_weekday = weekday_data.shape[0]
    exceeding_sequences_weekday = weekday_data[weekday_data['Total_Hour_Count'] > threshold].shape[0]
    percentage_exceed_weekday = (exceeding_sequences_weekday / total_num_stops) * 100 if num_hours_low_ridership_weekday else 0
    print(f"Percentage of stop sequences exceeding {threshold} (weekday): {percentage_exceed_weekday:.2f}%")
    
    
    weekend_data = hour_counts[hour_counts['DAY_TYPE'] == 'WEEKENDS/HOLIDAY']
    num_hours_low_ridership_weekend = weekend_data.shape[0]
    exceeding_sequences_weekend = weekend_data[weekend_data['Total_Hour_Count'] > threshold].shape[0]
    percentage_exceed_weekend = (exceeding_sequences_weekend / total_num_stops) * 100 if num_hours_low_ridership_weekend else 0
    print(f"Percentage of stop sequences exceeding {threshold} (weekend): {percentage_exceed_weekend:.2f}%")
    return percentage_exceed_weekday, percentage_exceed_weekend


# List to store each service's results
results = []
threshold = 6
for service in unique_services:
    hour_count_by_stop_sequence, total_num_stops = get_hour_count_below_25th_percentile_each_stop(service, bus_routes_trips, ridership, ridership_percentiles)
    percentage_exceed_weekday, percentage_exceed_weekend = percentage_exceeding_threshold(hour_count_by_stop_sequence, total_num_stops, threshold)
    # Append the results to the list
    result = {
        'ServiceNo': service,
        'Weekday_Percentage_Exceed': percentage_exceed_weekday,
        'Weekend_Percentage_Exceed': percentage_exceed_weekend
    }
    results.append(result)
    print(result)

# Convert the results list into a DataFrame
ridership_percentage_df = pd.DataFrame(results)
# Out:
# Percentage of stop sequences exceeding 6 (weekday): 19.23%
# Percentage of stop sequences exceeding 6 (weekend): 11.54%
# {'ServiceNo': '118', 'Weekday_Percentage_Exceed': 19.230769230769234, 'Weekend_Percentage_Exceed': 11.538461538461538}
# Percentage of stop sequences exceeding 6 (weekday): 95.24%
# Percentage of stop sequences exceeding 6 (weekend): 85.71%
# {'ServiceNo': '118A', 'Weekday_Percentage_Exceed': 95.23809523809523, 'Weekend_Percentage_Exceed': 85.71428571428571}
# Percentage of stop sequences exceeding 6 (weekday): 93.75%
# Percentage of stop sequences exceeding 6 (weekend): 87.50%
# {'ServiceNo': '118B', 'Weekday_Percentage_Exceed': 93.75, 'Weekend_Percentage_Exceed': 87.5}
# Percentage of stop sequences exceeding 6 (weekday): 22.92%
# Percentage of stop sequences exceeding 6 (weekend): 6.25%
# {'ServiceNo': '119', 'Weekday_Percentage_Exceed': 22.916666666666664, 'Weekend_Percentage_Exceed': 6.25}
# Percentage of stop sequences exceeding 6 (weekday): 21.43%
# Percentage of stop sequences exceeding 6 (weekend): 10.00%
# {'ServiceNo': '12', 'Weekday_Percentage_Exceed': 21.428571428571427, 'Weekend_Percentage_Exceed': 10.0}
# Percentage of stop sequences exceeding 6 (weekday): 53.66%
# Percentage of stop sequences exceeding 6 (weekend): 31.71%
# {'ServiceNo': '12e', 'Weekday_Percentage_Exceed': 53.65853658536586, 'Weekend_Percentage_Exceed': 31.70731707317073}
# Percentage of stop sequences exceeding 6 (weekday): 20.00%
# Percentage of stop sequences exceeding 6 (weekend): 12.50%
# {'ServiceNo': '136', 'Weekday_Percentage_Exceed': 20.0, 'Weekend_Percentage_Exceed': 12.5}
# Percentage of stop sequences exceeding 6 (weekday): 17.39%
# Percentage of stop sequences exceeding 6 (weekend): 1.45%
# {'ServiceNo': '15', 'Weekday_Percentage_Exceed': 17.391304347826086, 'Weekend_Percentage_Exceed': 1.4492753623188406}
# Percentage of stop sequences exceeding 6 (weekday): 92.00%
# Percentage of stop sequences exceeding 6 (weekend): 88.00%
# {'ServiceNo': '15A', 'Weekday_Percentage_Exceed': 92.0, 'Weekend_Percentage_Exceed': 88.0}
# Percentage of stop sequences exceeding 6 (weekday): 12.90%
# Percentage of stop sequences exceeding 6 (weekend): 6.45%
# {'ServiceNo': '17', 'Weekday_Percentage_Exceed': 12.903225806451612, 'Weekend_Percentage_Exceed': 6.451612903225806}
# Percentage of stop sequences exceeding 6 (weekday): 20.00%
# Percentage of stop sequences exceeding 6 (weekend): 20.00%
# {'ServiceNo': '17A', 'Weekday_Percentage_Exceed': 20.0, 'Weekend_Percentage_Exceed': 20.0}
# Percentage of stop sequences exceeding 6 (weekday): 21.74%
# Percentage of stop sequences exceeding 6 (weekend): 10.14%
# {'ServiceNo': '2', 'Weekday_Percentage_Exceed': 21.73913043478261, 'Weekend_Percentage_Exceed': 10.144927536231885}
# Percentage of stop sequences exceeding 6 (weekday): 63.64%
# Percentage of stop sequences exceeding 6 (weekend): 36.36%
# {'ServiceNo': '2B', 'Weekday_Percentage_Exceed': 63.63636363636363, 'Weekend_Percentage_Exceed': 36.36363636363637}
# Percentage of stop sequences exceeding 6 (weekday): 20.51%
# Percentage of stop sequences exceeding 6 (weekend): 5.13%
# {'ServiceNo': '3', 'Weekday_Percentage_Exceed': 20.51282051282051, 'Weekend_Percentage_Exceed': 5.128205128205128}
# Percentage of stop sequences exceeding 6 (weekday): 14.29%
# Percentage of stop sequences exceeding 6 (weekend): 8.93%
# {'ServiceNo': '34', 'Weekday_Percentage_Exceed': 14.285714285714285, 'Weekend_Percentage_Exceed': 8.928571428571429}
# Percentage of stop sequences exceeding 6 (weekday): 53.33%
# Percentage of stop sequences exceeding 6 (weekend): 33.33%
# {'ServiceNo': '34A', 'Weekday_Percentage_Exceed': 53.333333333333336, 'Weekend_Percentage_Exceed': 33.33333333333333}
# Percentage of stop sequences exceeding 6 (weekday): 93.48%
# Percentage of stop sequences exceeding 6 (weekend): 84.78%
# {'ServiceNo': '34B', 'Weekday_Percentage_Exceed': 93.47826086956522, 'Weekend_Percentage_Exceed': 84.78260869565217}
# Percentage of stop sequences exceeding 6 (weekday): 16.67%
# Percentage of stop sequences exceeding 6 (weekend): 8.33%
# {'ServiceNo': '354', 'Weekday_Percentage_Exceed': 16.666666666666664, 'Weekend_Percentage_Exceed': 8.333333333333332}
# Percentage of stop sequences exceeding 6 (weekday): 13.04%
# Percentage of stop sequences exceeding 6 (weekend): 8.70%
# {'ServiceNo': '358', 'Weekday_Percentage_Exceed': 13.043478260869565, 'Weekend_Percentage_Exceed': 8.695652173913043}
# Percentage of stop sequences exceeding 6 (weekday): 10.53%
# Percentage of stop sequences exceeding 6 (weekend): 7.89%
# {'ServiceNo': '359', 'Weekday_Percentage_Exceed': 10.526315789473683, 'Weekend_Percentage_Exceed': 7.894736842105263}
# Percentage of stop sequences exceeding 6 (weekday): 16.42%
# Percentage of stop sequences exceeding 6 (weekend): 4.48%
# {'ServiceNo': '36', 'Weekday_Percentage_Exceed': 16.417910447761194, 'Weekend_Percentage_Exceed': 4.477611940298507}
# Percentage of stop sequences exceeding 6 (weekday): 88.24%
# Percentage of stop sequences exceeding 6 (weekend): 85.29%
# {'ServiceNo': '36A', 'Weekday_Percentage_Exceed': 88.23529411764706, 'Weekend_Percentage_Exceed': 85.29411764705883}
# Percentage of stop sequences exceeding 6 (weekday): 87.27%
# Percentage of stop sequences exceeding 6 (weekend): 83.64%
# {'ServiceNo': '36B', 'Weekday_Percentage_Exceed': 87.27272727272727, 'Weekend_Percentage_Exceed': 83.63636363636363}
# Percentage of stop sequences exceeding 6 (weekday): 25.00%
# Percentage of stop sequences exceeding 6 (weekend): 7.14%
# {'ServiceNo': '381', 'Weekday_Percentage_Exceed': 25.0, 'Weekend_Percentage_Exceed': 7.142857142857142}
# Percentage of stop sequences exceeding 6 (weekday): 28.57%
# Percentage of stop sequences exceeding 6 (weekend): 14.29%
# {'ServiceNo': '382', 'Weekday_Percentage_Exceed': 28.57142857142857, 'Weekend_Percentage_Exceed': 14.285714285714285}
# Percentage of stop sequences exceeding 6 (weekday): 71.43%
# Percentage of stop sequences exceeding 6 (weekend): 42.86%
# {'ServiceNo': '382A', 'Weekday_Percentage_Exceed': 71.42857142857143, 'Weekend_Percentage_Exceed': 42.857142857142854}
# Percentage of stop sequences exceeding 6 (weekday): 26.67%
# Percentage of stop sequences exceeding 6 (weekend): 13.33%
# {'ServiceNo': '382G', 'Weekday_Percentage_Exceed': 26.666666666666668, 'Weekend_Percentage_Exceed': 13.333333333333334}
# Percentage of stop sequences exceeding 6 (weekday): 20.00%
# Percentage of stop sequences exceeding 6 (weekend): 6.67%
# {'ServiceNo': '382W', 'Weekday_Percentage_Exceed': 20.0, 'Weekend_Percentage_Exceed': 6.666666666666667}
# Percentage of stop sequences exceeding 6 (weekday): 50.00%
# Percentage of stop sequences exceeding 6 (weekend): 21.43%
# {'ServiceNo': '384', 'Weekday_Percentage_Exceed': 50.0, 'Weekend_Percentage_Exceed': 21.428571428571427}
# Percentage of stop sequences exceeding 6 (weekday): 50.00%
# Percentage of stop sequences exceeding 6 (weekend): 30.00%
# {'ServiceNo': '386', 'Weekday_Percentage_Exceed': 50.0, 'Weekend_Percentage_Exceed': 30.0}
# Percentage of stop sequences exceeding 6 (weekday): 85.71%
# Percentage of stop sequences exceeding 6 (weekend): 71.43%
# {'ServiceNo': '386A', 'Weekday_Percentage_Exceed': 85.71428571428571, 'Weekend_Percentage_Exceed': 71.42857142857143}
# Percentage of stop sequences exceeding 6 (weekday): 96.43%
# Percentage of stop sequences exceeding 6 (weekend): 85.71%
# {'ServiceNo': '3A', 'Weekday_Percentage_Exceed': 96.42857142857143, 'Weekend_Percentage_Exceed': 85.71428571428571}
# Percentage of stop sequences exceeding 6 (weekday): 13.04%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '403', 'Weekday_Percentage_Exceed': 13.043478260869565, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 25.81%
# Percentage of stop sequences exceeding 6 (weekend): 8.06%
# {'ServiceNo': '43', 'Weekday_Percentage_Exceed': 25.806451612903224, 'Weekend_Percentage_Exceed': 8.064516129032258}
# Percentage of stop sequences exceeding 6 (weekday): 82.14%
# Percentage of stop sequences exceeding 6 (weekend): 53.57%
# {'ServiceNo': '43e', 'Weekday_Percentage_Exceed': 82.14285714285714, 'Weekend_Percentage_Exceed': 53.57142857142857}
# Percentage of stop sequences exceeding 6 (weekday): 25.00%
# Percentage of stop sequences exceeding 6 (weekend): 12.50%
# {'ServiceNo': '43M', 'Weekday_Percentage_Exceed': 25.0, 'Weekend_Percentage_Exceed': 12.5}
# Percentage of stop sequences exceeding 6 (weekday): 29.90%
# Percentage of stop sequences exceeding 6 (weekend): 11.34%
# {'ServiceNo': '518', 'Weekday_Percentage_Exceed': 29.896907216494846, 'Weekend_Percentage_Exceed': 11.34020618556701}
# Percentage of stop sequences exceeding 6 (weekday): 90.70%
# Percentage of stop sequences exceeding 6 (weekend): 81.40%
# {'ServiceNo': '518A', 'Weekday_Percentage_Exceed': 90.69767441860465, 'Weekend_Percentage_Exceed': 81.3953488372093}
# Percentage of stop sequences exceeding 6 (weekday): 10.00%
# Percentage of stop sequences exceeding 6 (weekend): 3.33%
# {'ServiceNo': '6', 'Weekday_Percentage_Exceed': 10.0, 'Weekend_Percentage_Exceed': 3.3333333333333335}
# Percentage of stop sequences exceeding 6 (weekday): 22.73%
# Percentage of stop sequences exceeding 6 (weekend): 6.82%
# {'ServiceNo': '62', 'Weekday_Percentage_Exceed': 22.727272727272727, 'Weekend_Percentage_Exceed': 6.8181818181818175}
# Percentage of stop sequences exceeding 6 (weekday): 92.68%
# Percentage of stop sequences exceeding 6 (weekend): 78.05%
# {'ServiceNo': '62A', 'Weekday_Percentage_Exceed': 92.6829268292683, 'Weekend_Percentage_Exceed': 78.04878048780488}
# Percentage of stop sequences exceeding 6 (weekday): 47.06%
# Percentage of stop sequences exceeding 6 (weekend): 47.06%
# {'ServiceNo': '661', 'Weekday_Percentage_Exceed': 47.05882352941176, 'Weekend_Percentage_Exceed': 47.05882352941176}
# Percentage of stop sequences exceeding 6 (weekday): 76.47%
# Percentage of stop sequences exceeding 6 (weekend): 76.47%
# {'ServiceNo': '666', 'Weekday_Percentage_Exceed': 76.47058823529412, 'Weekend_Percentage_Exceed': 76.47058823529412}
# Percentage of stop sequences exceeding 6 (weekday): 22.73%
# Percentage of stop sequences exceeding 6 (weekend): 6.82%
# {'ServiceNo': '68', 'Weekday_Percentage_Exceed': 22.727272727272727, 'Weekend_Percentage_Exceed': 6.8181818181818175}
# Percentage of stop sequences exceeding 6 (weekday): 75.00%
# Percentage of stop sequences exceeding 6 (weekend): 75.00%
# {'ServiceNo': '68A', 'Weekday_Percentage_Exceed': 75.0, 'Weekend_Percentage_Exceed': 75.0}
# Percentage of stop sequences exceeding 6 (weekday): 75.00%
# Percentage of stop sequences exceeding 6 (weekend): 62.50%
# {'ServiceNo': '68B', 'Weekday_Percentage_Exceed': 75.0, 'Weekend_Percentage_Exceed': 62.5}
# Percentage of stop sequences exceeding 6 (weekday): 41.86%
# Percentage of stop sequences exceeding 6 (weekend): 13.95%
# {'ServiceNo': '82', 'Weekday_Percentage_Exceed': 41.86046511627907, 'Weekend_Percentage_Exceed': 13.953488372093023}
# Percentage of stop sequences exceeding 6 (weekday): 35.48%
# Percentage of stop sequences exceeding 6 (weekend): 6.45%
# {'ServiceNo': '83', 'Weekday_Percentage_Exceed': 35.483870967741936, 'Weekend_Percentage_Exceed': 6.451612903225806}
# Percentage of stop sequences exceeding 6 (weekday): 93.75%
# Percentage of stop sequences exceeding 6 (weekend): 87.50%
# {'ServiceNo': '83T', 'Weekday_Percentage_Exceed': 93.75, 'Weekend_Percentage_Exceed': 87.5}
# Percentage of stop sequences exceeding 6 (weekday): 66.67%
# Percentage of stop sequences exceeding 6 (weekend): 16.67%
# {'ServiceNo': '84A', 'Weekday_Percentage_Exceed': 66.66666666666666, 'Weekend_Percentage_Exceed': 16.666666666666664}
# Percentage of stop sequences exceeding 6 (weekday): 29.41%
# Percentage of stop sequences exceeding 6 (weekend): 17.65%
# {'ServiceNo': '84G', 'Weekday_Percentage_Exceed': 29.411764705882355, 'Weekend_Percentage_Exceed': 17.647058823529413}
# Percentage of stop sequences exceeding 6 (weekday): 29.41%
# Percentage of stop sequences exceeding 6 (weekend): 11.76%
# {'ServiceNo': '84W', 'Weekday_Percentage_Exceed': 29.411764705882355, 'Weekend_Percentage_Exceed': 11.76470588235294}
# Percentage of stop sequences exceeding 6 (weekday): 3.23%
# Percentage of stop sequences exceeding 6 (weekend): 3.23%
# {'ServiceNo': '85', 'Weekday_Percentage_Exceed': 3.225806451612903, 'Weekend_Percentage_Exceed': 3.225806451612903}
# Percentage of stop sequences exceeding 6 (weekday): 60.00%
# Percentage of stop sequences exceeding 6 (weekend): 50.00%
# {'ServiceNo': '85A', 'Weekday_Percentage_Exceed': 60.0, 'Weekend_Percentage_Exceed': 50.0}
# Percentage of stop sequences exceeding 6 (weekday): 13.51%
# Percentage of stop sequences exceeding 6 (weekend): 2.70%
# {'ServiceNo': '10', 'Weekday_Percentage_Exceed': 13.513513513513514, 'Weekend_Percentage_Exceed': 2.7027027027027026}
# Percentage of stop sequences exceeding 6 (weekday): 18.97%
# Percentage of stop sequences exceeding 6 (weekend): 10.34%
# {'ServiceNo': '100', 'Weekday_Percentage_Exceed': 18.96551724137931, 'Weekend_Percentage_Exceed': 10.344827586206897}
# Percentage of stop sequences exceeding 6 (weekday): 92.31%
# Percentage of stop sequences exceeding 6 (weekend): 69.23%
# {'ServiceNo': '100A', 'Weekday_Percentage_Exceed': 92.3076923076923, 'Weekend_Percentage_Exceed': 69.23076923076923}
# Percentage of stop sequences exceeding 6 (weekday): 17.02%
# Percentage of stop sequences exceeding 6 (weekend): 6.38%
# {'ServiceNo': '101', 'Weekday_Percentage_Exceed': 17.02127659574468, 'Weekend_Percentage_Exceed': 6.382978723404255}
# Percentage of stop sequences exceeding 6 (weekday): 23.33%
# Percentage of stop sequences exceeding 6 (weekend): 8.33%
# {'ServiceNo': '102', 'Weekday_Percentage_Exceed': 23.333333333333332, 'Weekend_Percentage_Exceed': 8.333333333333332}
# Percentage of stop sequences exceeding 6 (weekday): 81.82%
# Percentage of stop sequences exceeding 6 (weekend): 72.73%
# {'ServiceNo': '102A', 'Weekday_Percentage_Exceed': 81.81818181818183, 'Weekend_Percentage_Exceed': 72.72727272727273}
# Percentage of stop sequences exceeding 6 (weekday): 72.73%
# Percentage of stop sequences exceeding 6 (weekend): 63.64%
# {'ServiceNo': '102B', 'Weekday_Percentage_Exceed': 72.72727272727273, 'Weekend_Percentage_Exceed': 63.63636363636363}
# Percentage of stop sequences exceeding 6 (weekday): 12.50%
# Percentage of stop sequences exceeding 6 (weekend): 2.50%
# {'ServiceNo': '103', 'Weekday_Percentage_Exceed': 12.5, 'Weekend_Percentage_Exceed': 2.5}
# Percentage of stop sequences exceeding 6 (weekday): 31.58%
# Percentage of stop sequences exceeding 6 (weekend): 14.04%
# {'ServiceNo': '105', 'Weekday_Percentage_Exceed': 31.57894736842105, 'Weekend_Percentage_Exceed': 14.035087719298245}
# Percentage of stop sequences exceeding 6 (weekday): 92.31%
# Percentage of stop sequences exceeding 6 (weekend): 76.92%
# {'ServiceNo': '105B', 'Weekday_Percentage_Exceed': 92.3076923076923, 'Weekend_Percentage_Exceed': 76.92307692307693}
# Percentage of stop sequences exceeding 6 (weekday): 30.77%
# Percentage of stop sequences exceeding 6 (weekend): 12.82%
# {'ServiceNo': '107', 'Weekday_Percentage_Exceed': 30.76923076923077, 'Weekend_Percentage_Exceed': 12.82051282051282}
# Percentage of stop sequences exceeding 6 (weekday): 42.65%
# Percentage of stop sequences exceeding 6 (weekend): 16.18%
# {'ServiceNo': '107M', 'Weekday_Percentage_Exceed': 42.64705882352941, 'Weekend_Percentage_Exceed': 16.176470588235293}
# Percentage of stop sequences exceeding 6 (weekday): 21.57%
# Percentage of stop sequences exceeding 6 (weekend): 5.88%
# {'ServiceNo': '109', 'Weekday_Percentage_Exceed': 21.568627450980394, 'Weekend_Percentage_Exceed': 5.88235294117647}
# Percentage of stop sequences exceeding 6 (weekday): 93.33%
# Percentage of stop sequences exceeding 6 (weekend): 80.00%
# {'ServiceNo': '109A', 'Weekday_Percentage_Exceed': 93.33333333333333, 'Weekend_Percentage_Exceed': 80.0}
# Percentage of stop sequences exceeding 6 (weekday): 90.00%
# Percentage of stop sequences exceeding 6 (weekend): 80.00%
# {'ServiceNo': '10e', 'Weekday_Percentage_Exceed': 90.0, 'Weekend_Percentage_Exceed': 80.0}
# Percentage of stop sequences exceeding 6 (weekday): 36.00%
# Percentage of stop sequences exceeding 6 (weekend): 12.00%
# {'ServiceNo': '11', 'Weekday_Percentage_Exceed': 36.0, 'Weekend_Percentage_Exceed': 12.0}
# Percentage of stop sequences exceeding 6 (weekday): 24.56%
# Percentage of stop sequences exceeding 6 (weekend): 10.53%
# {'ServiceNo': '111', 'Weekday_Percentage_Exceed': 24.561403508771928, 'Weekend_Percentage_Exceed': 10.526315789473683}
# Percentage of stop sequences exceeding 6 (weekday): 25.53%
# Percentage of stop sequences exceeding 6 (weekend): 6.38%
# {'ServiceNo': '112', 'Weekday_Percentage_Exceed': 25.53191489361702, 'Weekend_Percentage_Exceed': 6.382978723404255}
# Percentage of stop sequences exceeding 6 (weekday): 75.00%
# Percentage of stop sequences exceeding 6 (weekend): 75.00%
# {'ServiceNo': '112A', 'Weekday_Percentage_Exceed': 75.0, 'Weekend_Percentage_Exceed': 75.0}
# Percentage of stop sequences exceeding 6 (weekday): 27.27%
# Percentage of stop sequences exceeding 6 (weekend): 6.82%
# {'ServiceNo': '113', 'Weekday_Percentage_Exceed': 27.27272727272727, 'Weekend_Percentage_Exceed': 6.8181818181818175}
# Percentage of stop sequences exceeding 6 (weekday): 95.00%
# Percentage of stop sequences exceeding 6 (weekend): 75.00%
# {'ServiceNo': '113A', 'Weekday_Percentage_Exceed': 95.0, 'Weekend_Percentage_Exceed': 75.0}
# Percentage of stop sequences exceeding 6 (weekday): 22.22%
# Percentage of stop sequences exceeding 6 (weekend): 11.11%
# {'ServiceNo': '114', 'Weekday_Percentage_Exceed': 22.22222222222222, 'Weekend_Percentage_Exceed': 11.11111111111111}
# Percentage of stop sequences exceeding 6 (weekday): 50.00%
# Percentage of stop sequences exceeding 6 (weekend): 50.00%
# {'ServiceNo': '114A', 'Weekday_Percentage_Exceed': 50.0, 'Weekend_Percentage_Exceed': 50.0}
# Percentage of stop sequences exceeding 6 (weekday): 38.46%
# Percentage of stop sequences exceeding 6 (weekend): 7.69%
# {'ServiceNo': '115', 'Weekday_Percentage_Exceed': 38.46153846153847, 'Weekend_Percentage_Exceed': 7.6923076923076925}
# Percentage of stop sequences exceeding 6 (weekday): 5.41%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '116', 'Weekday_Percentage_Exceed': 5.405405405405405, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 81.82%
# Percentage of stop sequences exceeding 6 (weekend): 81.82%
# {'ServiceNo': '116A', 'Weekday_Percentage_Exceed': 81.81818181818183, 'Weekend_Percentage_Exceed': 81.81818181818183}
# Percentage of stop sequences exceeding 6 (weekday): 26.83%
# Percentage of stop sequences exceeding 6 (weekend): 12.20%
# {'ServiceNo': '117', 'Weekday_Percentage_Exceed': 26.82926829268293, 'Weekend_Percentage_Exceed': 12.195121951219512}
# Percentage of stop sequences exceeding 6 (weekday): 30.00%
# Percentage of stop sequences exceeding 6 (weekend): 20.00%
# {'ServiceNo': '117A', 'Weekday_Percentage_Exceed': 30.0, 'Weekend_Percentage_Exceed': 20.0}
# Percentage of stop sequences exceeding 6 (weekday): 47.62%
# Percentage of stop sequences exceeding 6 (weekend): 42.86%
# {'ServiceNo': '117M', 'Weekday_Percentage_Exceed': 47.61904761904761, 'Weekend_Percentage_Exceed': 42.857142857142854}
# Percentage of stop sequences exceeding 6 (weekday): 24.00%
# Percentage of stop sequences exceeding 6 (weekend): 8.00%
# {'ServiceNo': '120', 'Weekday_Percentage_Exceed': 24.0, 'Weekend_Percentage_Exceed': 8.0}
# Percentage of stop sequences exceeding 6 (weekday): 28.57%
# Percentage of stop sequences exceeding 6 (weekend): 7.14%
# {'ServiceNo': '121', 'Weekday_Percentage_Exceed': 28.57142857142857, 'Weekend_Percentage_Exceed': 7.142857142857142}
# Percentage of stop sequences exceeding 6 (weekday): 30.77%
# Percentage of stop sequences exceeding 6 (weekend): 17.95%
# {'ServiceNo': '122', 'Weekday_Percentage_Exceed': 30.76923076923077, 'Weekend_Percentage_Exceed': 17.94871794871795}
# Percentage of stop sequences exceeding 6 (weekday): 32.56%
# Percentage of stop sequences exceeding 6 (weekend): 9.30%
# {'ServiceNo': '123', 'Weekday_Percentage_Exceed': 32.55813953488372, 'Weekend_Percentage_Exceed': 9.30232558139535}
# Percentage of stop sequences exceeding 6 (weekday): 32.00%
# Percentage of stop sequences exceeding 6 (weekend): 16.00%
# {'ServiceNo': '123M', 'Weekday_Percentage_Exceed': 32.0, 'Weekend_Percentage_Exceed': 16.0}
# Percentage of stop sequences exceeding 6 (weekday): 18.75%
# Percentage of stop sequences exceeding 6 (weekend): 2.08%
# {'ServiceNo': '124', 'Weekday_Percentage_Exceed': 18.75, 'Weekend_Percentage_Exceed': 2.083333333333333}
# Percentage of stop sequences exceeding 6 (weekday): 31.37%
# Percentage of stop sequences exceeding 6 (weekend): 11.76%
# {'ServiceNo': '125', 'Weekday_Percentage_Exceed': 31.372549019607842, 'Weekend_Percentage_Exceed': 11.76470588235294}
# Percentage of stop sequences exceeding 6 (weekday): 66.67%
# Percentage of stop sequences exceeding 6 (weekend): 22.22%
# {'ServiceNo': '125A', 'Weekday_Percentage_Exceed': 66.66666666666666, 'Weekend_Percentage_Exceed': 22.22222222222222}
# Percentage of stop sequences exceeding 6 (weekday): 18.18%
# Percentage of stop sequences exceeding 6 (weekend): 13.64%
# {'ServiceNo': '127', 'Weekday_Percentage_Exceed': 18.181818181818183, 'Weekend_Percentage_Exceed': 13.636363636363635}
# Percentage of stop sequences exceeding 6 (weekday): 66.67%
# Percentage of stop sequences exceeding 6 (weekend): 33.33%
# {'ServiceNo': '127A', 'Weekday_Percentage_Exceed': 66.66666666666666, 'Weekend_Percentage_Exceed': 33.33333333333333}
# Percentage of stop sequences exceeding 6 (weekday): 28.21%
# Percentage of stop sequences exceeding 6 (weekend): 15.38%
# {'ServiceNo': '129', 'Weekday_Percentage_Exceed': 28.205128205128204, 'Weekend_Percentage_Exceed': 15.384615384615385}
# Percentage of stop sequences exceeding 6 (weekday): 80.00%
# Percentage of stop sequences exceeding 6 (weekend): 80.00%
# {'ServiceNo': '129A', 'Weekday_Percentage_Exceed': 80.0, 'Weekend_Percentage_Exceed': 80.0}
# Percentage of stop sequences exceeding 6 (weekday): 42.86%
# Percentage of stop sequences exceeding 6 (weekend): 28.57%
# {'ServiceNo': '129B', 'Weekday_Percentage_Exceed': 42.857142857142854, 'Weekend_Percentage_Exceed': 28.57142857142857}
# Percentage of stop sequences exceeding 6 (weekday): 37.50%
# Percentage of stop sequences exceeding 6 (weekend): 10.94%
# {'ServiceNo': '13', 'Weekday_Percentage_Exceed': 37.5, 'Weekend_Percentage_Exceed': 10.9375}
# Percentage of stop sequences exceeding 6 (weekday): 23.81%
# Percentage of stop sequences exceeding 6 (weekend): 4.76%
# {'ServiceNo': '130', 'Weekday_Percentage_Exceed': 23.809523809523807, 'Weekend_Percentage_Exceed': 4.761904761904762}
# Percentage of stop sequences exceeding 6 (weekday): 14.00%
# Percentage of stop sequences exceeding 6 (weekend): 6.00%
# {'ServiceNo': '131', 'Weekday_Percentage_Exceed': 14.000000000000002, 'Weekend_Percentage_Exceed': 6.0}
# Percentage of stop sequences exceeding 6 (weekday): 93.55%
# Percentage of stop sequences exceeding 6 (weekend): 90.32%
# {'ServiceNo': '131A', 'Weekday_Percentage_Exceed': 93.54838709677419, 'Weekend_Percentage_Exceed': 90.32258064516128}
# Percentage of stop sequences exceeding 6 (weekday): 28.07%
# Percentage of stop sequences exceeding 6 (weekend): 12.28%
# {'ServiceNo': '132', 'Weekday_Percentage_Exceed': 28.07017543859649, 'Weekend_Percentage_Exceed': 12.280701754385964}
# Percentage of stop sequences exceeding 6 (weekday): 32.56%
# Percentage of stop sequences exceeding 6 (weekend): 9.30%
# {'ServiceNo': '133', 'Weekday_Percentage_Exceed': 32.55813953488372, 'Weekend_Percentage_Exceed': 9.30232558139535}
# Percentage of stop sequences exceeding 6 (weekday): 21.62%
# Percentage of stop sequences exceeding 6 (weekend): 13.51%
# {'ServiceNo': '134', 'Weekday_Percentage_Exceed': 21.62162162162162, 'Weekend_Percentage_Exceed': 13.513513513513514}
# Percentage of stop sequences exceeding 6 (weekday): 24.44%
# Percentage of stop sequences exceeding 6 (weekend): 11.11%
# {'ServiceNo': '135', 'Weekday_Percentage_Exceed': 24.444444444444443, 'Weekend_Percentage_Exceed': 11.11111111111111}
# Percentage of stop sequences exceeding 6 (weekday): 30.43%
# Percentage of stop sequences exceeding 6 (weekend): 21.74%
# {'ServiceNo': '137', 'Weekday_Percentage_Exceed': 30.434782608695656, 'Weekend_Percentage_Exceed': 21.73913043478261}
# Percentage of stop sequences exceeding 6 (weekday): 90.91%
# Percentage of stop sequences exceeding 6 (weekend): 90.91%
# {'ServiceNo': '137A', 'Weekday_Percentage_Exceed': 90.9090909090909, 'Weekend_Percentage_Exceed': 90.9090909090909}
# Percentage of stop sequences exceeding 6 (weekday): 11.86%
# Percentage of stop sequences exceeding 6 (weekend): 3.39%
# {'ServiceNo': '138', 'Weekday_Percentage_Exceed': 11.864406779661017, 'Weekend_Percentage_Exceed': 3.389830508474576}
# Percentage of stop sequences exceeding 6 (weekday): 46.67%
# Percentage of stop sequences exceeding 6 (weekend): 23.33%
# {'ServiceNo': '138A', 'Weekday_Percentage_Exceed': 46.666666666666664, 'Weekend_Percentage_Exceed': 23.333333333333332}
# Percentage of stop sequences exceeding 6 (weekday): 88.89%
# Percentage of stop sequences exceeding 6 (weekend): 55.56%
# {'ServiceNo': '138B', 'Weekday_Percentage_Exceed': 88.88888888888889, 'Weekend_Percentage_Exceed': 55.55555555555556}
# Percentage of stop sequences exceeding 6 (weekday): 23.91%
# Percentage of stop sequences exceeding 6 (weekend): 6.52%
# {'ServiceNo': '139', 'Weekday_Percentage_Exceed': 23.91304347826087, 'Weekend_Percentage_Exceed': 6.521739130434782}
# Percentage of stop sequences exceeding 6 (weekday): 88.89%
# Percentage of stop sequences exceeding 6 (weekend): 88.89%
# {'ServiceNo': '139A', 'Weekday_Percentage_Exceed': 88.88888888888889, 'Weekend_Percentage_Exceed': 88.88888888888889}
# Percentage of stop sequences exceeding 6 (weekday): 83.33%
# Percentage of stop sequences exceeding 6 (weekend): 66.67%
# {'ServiceNo': '13A', 'Weekday_Percentage_Exceed': 83.33333333333334, 'Weekend_Percentage_Exceed': 66.66666666666666}
# Percentage of stop sequences exceeding 6 (weekday): 32.50%
# Percentage of stop sequences exceeding 6 (weekend): 8.75%
# {'ServiceNo': '14', 'Weekday_Percentage_Exceed': 32.5, 'Weekend_Percentage_Exceed': 8.75}
# Percentage of stop sequences exceeding 6 (weekday): 43.48%
# Percentage of stop sequences exceeding 6 (weekend): 21.74%
# {'ServiceNo': '140', 'Weekday_Percentage_Exceed': 43.47826086956522, 'Weekend_Percentage_Exceed': 21.73913043478261}
# Percentage of stop sequences exceeding 6 (weekday): 18.52%
# Percentage of stop sequences exceeding 6 (weekend): 3.70%
# {'ServiceNo': '141', 'Weekday_Percentage_Exceed': 18.51851851851852, 'Weekend_Percentage_Exceed': 3.7037037037037033}
# Percentage of stop sequences exceeding 6 (weekday): 14.29%
# Percentage of stop sequences exceeding 6 (weekend): 4.76%
# {'ServiceNo': '142', 'Weekday_Percentage_Exceed': 14.285714285714285, 'Weekend_Percentage_Exceed': 4.761904761904762}
# Percentage of stop sequences exceeding 6 (weekday): 87.50%
# Percentage of stop sequences exceeding 6 (weekend): 81.25%
# {'ServiceNo': '142A', 'Weekday_Percentage_Exceed': 87.5, 'Weekend_Percentage_Exceed': 81.25}
# Percentage of stop sequences exceeding 6 (weekday): 25.45%
# Percentage of stop sequences exceeding 6 (weekend): 10.91%
# {'ServiceNo': '145', 'Weekday_Percentage_Exceed': 25.454545454545453, 'Weekend_Percentage_Exceed': 10.909090909090908}
# Percentage of stop sequences exceeding 6 (weekday): 71.43%
# Percentage of stop sequences exceeding 6 (weekend): 57.14%
# {'ServiceNo': '145A', 'Weekday_Percentage_Exceed': 71.42857142857143, 'Weekend_Percentage_Exceed': 57.14285714285714}
# Percentage of stop sequences exceeding 6 (weekday): 31.25%
# Percentage of stop sequences exceeding 6 (weekend): 18.75%
# {'ServiceNo': '146', 'Weekday_Percentage_Exceed': 31.25, 'Weekend_Percentage_Exceed': 18.75}
# Percentage of stop sequences exceeding 6 (weekday): 28.00%
# Percentage of stop sequences exceeding 6 (weekend): 10.67%
# {'ServiceNo': '147', 'Weekday_Percentage_Exceed': 28.000000000000004, 'Weekend_Percentage_Exceed': 10.666666666666668}
# Percentage of stop sequences exceeding 6 (weekday): 85.11%
# Percentage of stop sequences exceeding 6 (weekend): 61.70%
# {'ServiceNo': '147A', 'Weekday_Percentage_Exceed': 85.1063829787234, 'Weekend_Percentage_Exceed': 61.702127659574465}
# Percentage of stop sequences exceeding 6 (weekday): 56.86%
# Percentage of stop sequences exceeding 6 (weekend): 37.25%
# {'ServiceNo': '14A', 'Weekday_Percentage_Exceed': 56.86274509803921, 'Weekend_Percentage_Exceed': 37.254901960784316}
# Percentage of stop sequences exceeding 6 (weekday): 70.00%
# Percentage of stop sequences exceeding 6 (weekend): 70.00%
# {'ServiceNo': '14e', 'Weekday_Percentage_Exceed': 70.0, 'Weekend_Percentage_Exceed': 70.0}
# Percentage of stop sequences exceeding 6 (weekday): 23.81%
# Percentage of stop sequences exceeding 6 (weekend): 14.29%
# {'ServiceNo': '150', 'Weekday_Percentage_Exceed': 23.809523809523807, 'Weekend_Percentage_Exceed': 14.285714285714285}
# Percentage of stop sequences exceeding 6 (weekday): 22.22%
# Percentage of stop sequences exceeding 6 (weekend): 11.11%
# {'ServiceNo': '151', 'Weekday_Percentage_Exceed': 22.22222222222222, 'Weekend_Percentage_Exceed': 11.11111111111111}
# Percentage of stop sequences exceeding 6 (weekday): 26.67%
# Percentage of stop sequences exceeding 6 (weekend): 13.33%
# {'ServiceNo': '153', 'Weekday_Percentage_Exceed': 26.666666666666668, 'Weekend_Percentage_Exceed': 13.333333333333334}
# Percentage of stop sequences exceeding 6 (weekday): 22.39%
# Percentage of stop sequences exceeding 6 (weekend): 5.97%
# {'ServiceNo': '154', 'Weekday_Percentage_Exceed': 22.388059701492537, 'Weekend_Percentage_Exceed': 5.970149253731343}
# Percentage of stop sequences exceeding 6 (weekday): 77.78%
# Percentage of stop sequences exceeding 6 (weekend): 33.33%
# {'ServiceNo': '154A', 'Weekday_Percentage_Exceed': 77.77777777777779, 'Weekend_Percentage_Exceed': 33.33333333333333}
# Percentage of stop sequences exceeding 6 (weekday): 81.25%
# Percentage of stop sequences exceeding 6 (weekend): 65.62%
# {'ServiceNo': '154B', 'Weekday_Percentage_Exceed': 81.25, 'Weekend_Percentage_Exceed': 65.625}
# Percentage of stop sequences exceeding 6 (weekday): 37.04%
# Percentage of stop sequences exceeding 6 (weekend): 16.67%
# {'ServiceNo': '155', 'Weekday_Percentage_Exceed': 37.03703703703704, 'Weekend_Percentage_Exceed': 16.666666666666664}
# Percentage of stop sequences exceeding 6 (weekday): 18.75%
# Percentage of stop sequences exceeding 6 (weekend): 9.38%
# {'ServiceNo': '156', 'Weekday_Percentage_Exceed': 18.75, 'Weekend_Percentage_Exceed': 9.375}
# Percentage of stop sequences exceeding 6 (weekday): 25.86%
# Percentage of stop sequences exceeding 6 (weekend): 10.34%
# {'ServiceNo': '157', 'Weekday_Percentage_Exceed': 25.862068965517242, 'Weekend_Percentage_Exceed': 10.344827586206897}
# Percentage of stop sequences exceeding 6 (weekday): 34.29%
# Percentage of stop sequences exceeding 6 (weekend): 14.29%
# {'ServiceNo': '158', 'Weekday_Percentage_Exceed': 34.285714285714285, 'Weekend_Percentage_Exceed': 14.285714285714285}
# Percentage of stop sequences exceeding 6 (weekday): 77.78%
# Percentage of stop sequences exceeding 6 (weekend): 70.37%
# {'ServiceNo': '158A', 'Weekday_Percentage_Exceed': 77.77777777777779, 'Weekend_Percentage_Exceed': 70.37037037037037}
# Percentage of stop sequences exceeding 6 (weekday): 17.95%
# Percentage of stop sequences exceeding 6 (weekend): 5.13%
# {'ServiceNo': '159', 'Weekday_Percentage_Exceed': 17.94871794871795, 'Weekend_Percentage_Exceed': 5.128205128205128}
# Percentage of stop sequences exceeding 6 (weekday): 68.00%
# Percentage of stop sequences exceeding 6 (weekend): 28.00%
# {'ServiceNo': '159A', 'Weekday_Percentage_Exceed': 68.0, 'Weekend_Percentage_Exceed': 28.000000000000004}
# Percentage of stop sequences exceeding 6 (weekday): 80.00%
# Percentage of stop sequences exceeding 6 (weekend): 80.00%
# {'ServiceNo': '159B', 'Weekday_Percentage_Exceed': 80.0, 'Weekend_Percentage_Exceed': 80.0}
# Percentage of stop sequences exceeding 6 (weekday): 36.73%
# Percentage of stop sequences exceeding 6 (weekend): 10.20%
# {'ServiceNo': '16', 'Weekday_Percentage_Exceed': 36.734693877551024, 'Weekend_Percentage_Exceed': 10.204081632653061}
# Percentage of stop sequences exceeding 6 (weekday): 17.50%
# Percentage of stop sequences exceeding 6 (weekend): 6.25%
# {'ServiceNo': '160', 'Weekday_Percentage_Exceed': 17.5, 'Weekend_Percentage_Exceed': 6.25}
# Percentage of stop sequences exceeding 6 (weekday): 8.33%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '160A', 'Weekday_Percentage_Exceed': 8.333333333333332, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 17.39%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '161', 'Weekday_Percentage_Exceed': 17.391304347826086, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 29.82%
# Percentage of stop sequences exceeding 6 (weekend): 15.79%
# {'ServiceNo': '162', 'Weekday_Percentage_Exceed': 29.82456140350877, 'Weekend_Percentage_Exceed': 15.789473684210526}
# Percentage of stop sequences exceeding 6 (weekday): 13.73%
# Percentage of stop sequences exceeding 6 (weekend): 1.96%
# {'ServiceNo': '163', 'Weekday_Percentage_Exceed': 13.725490196078432, 'Weekend_Percentage_Exceed': 1.9607843137254901}
# Percentage of stop sequences exceeding 6 (weekday): 82.35%
# Percentage of stop sequences exceeding 6 (weekend): 76.47%
# {'ServiceNo': '163A', 'Weekday_Percentage_Exceed': 82.35294117647058, 'Weekend_Percentage_Exceed': 76.47058823529412}
# Percentage of stop sequences exceeding 6 (weekday): 76.92%
# Percentage of stop sequences exceeding 6 (weekend): 53.85%
# {'ServiceNo': '163B', 'Weekday_Percentage_Exceed': 76.92307692307693, 'Weekend_Percentage_Exceed': 53.84615384615385}
# Percentage of stop sequences exceeding 6 (weekday): 18.33%
# Percentage of stop sequences exceeding 6 (weekend): 5.00%
# {'ServiceNo': '165', 'Weekday_Percentage_Exceed': 18.333333333333332, 'Weekend_Percentage_Exceed': 5.0}
# Percentage of stop sequences exceeding 6 (weekday): 25.00%
# Percentage of stop sequences exceeding 6 (weekend): 5.88%
# {'ServiceNo': '166', 'Weekday_Percentage_Exceed': 25.0, 'Weekend_Percentage_Exceed': 5.88235294117647}
# Percentage of stop sequences exceeding 6 (weekday): 18.52%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '168', 'Weekday_Percentage_Exceed': 18.51851851851852, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 87.50%
# Percentage of stop sequences exceeding 6 (weekend): 81.25%
# {'ServiceNo': '168A', 'Weekday_Percentage_Exceed': 87.5, 'Weekend_Percentage_Exceed': 81.25}
# Percentage of stop sequences exceeding 6 (weekday): 74.51%
# Percentage of stop sequences exceeding 6 (weekend): 58.82%
# {'ServiceNo': '16M', 'Weekday_Percentage_Exceed': 74.50980392156863, 'Weekend_Percentage_Exceed': 58.82352941176471}
# Percentage of stop sequences exceeding 6 (weekday): 31.82%
# Percentage of stop sequences exceeding 6 (weekend): 22.73%
# {'ServiceNo': '170', 'Weekday_Percentage_Exceed': 31.818181818181817, 'Weekend_Percentage_Exceed': 22.727272727272727}
# Percentage of stop sequences exceeding 6 (weekday): 37.50%
# Percentage of stop sequences exceeding 6 (weekend): 25.00%
# {'ServiceNo': '170X', 'Weekday_Percentage_Exceed': 37.5, 'Weekend_Percentage_Exceed': 25.0}
# Percentage of stop sequences exceeding 6 (weekday): 26.23%
# Percentage of stop sequences exceeding 6 (weekend): 8.20%
# {'ServiceNo': '174', 'Weekday_Percentage_Exceed': 26.229508196721312, 'Weekend_Percentage_Exceed': 8.19672131147541}
# Percentage of stop sequences exceeding 6 (weekday): 97.06%
# Percentage of stop sequences exceeding 6 (weekend): 94.12%
# {'ServiceNo': '174e', 'Weekday_Percentage_Exceed': 97.05882352941177, 'Weekend_Percentage_Exceed': 94.11764705882352}
# Percentage of stop sequences exceeding 6 (weekday): 38.60%
# Percentage of stop sequences exceeding 6 (weekend): 14.04%
# {'ServiceNo': '175', 'Weekday_Percentage_Exceed': 38.59649122807017, 'Weekend_Percentage_Exceed': 14.035087719298245}
# Percentage of stop sequences exceeding 6 (weekday): 36.67%
# Percentage of stop sequences exceeding 6 (weekend): 10.00%
# {'ServiceNo': '18', 'Weekday_Percentage_Exceed': 36.666666666666664, 'Weekend_Percentage_Exceed': 10.0}
# Percentage of stop sequences exceeding 6 (weekday): 39.53%
# Percentage of stop sequences exceeding 6 (weekend): 16.28%
# {'ServiceNo': '186', 'Weekday_Percentage_Exceed': 39.53488372093023, 'Weekend_Percentage_Exceed': 16.27906976744186}
# Percentage of stop sequences exceeding 6 (weekday): 8.93%
# Percentage of stop sequences exceeding 6 (weekend): 1.79%
# {'ServiceNo': '19', 'Weekday_Percentage_Exceed': 8.928571428571429, 'Weekend_Percentage_Exceed': 1.7857142857142856}
# Percentage of stop sequences exceeding 6 (weekday): 25.00%
# Percentage of stop sequences exceeding 6 (weekend): 10.00%
# {'ServiceNo': '191', 'Weekday_Percentage_Exceed': 25.0, 'Weekend_Percentage_Exceed': 10.0}
# Percentage of stop sequences exceeding 6 (weekday): 30.43%
# Percentage of stop sequences exceeding 6 (weekend): 14.49%
# {'ServiceNo': '195', 'Weekday_Percentage_Exceed': 30.434782608695656, 'Weekend_Percentage_Exceed': 14.492753623188406}
# Percentage of stop sequences exceeding 6 (weekday): 94.64%
# Percentage of stop sequences exceeding 6 (weekend): 73.21%
# {'ServiceNo': '195A', 'Weekday_Percentage_Exceed': 94.64285714285714, 'Weekend_Percentage_Exceed': 73.21428571428571}
# Percentage of stop sequences exceeding 6 (weekday): 22.06%
# Percentage of stop sequences exceeding 6 (weekend): 8.82%
# {'ServiceNo': '196', 'Weekday_Percentage_Exceed': 22.058823529411764, 'Weekend_Percentage_Exceed': 8.823529411764707}
# Percentage of stop sequences exceeding 6 (weekday): 97.06%
# Percentage of stop sequences exceeding 6 (weekend): 85.29%
# {'ServiceNo': '196A', 'Weekday_Percentage_Exceed': 97.05882352941177, 'Weekend_Percentage_Exceed': 85.29411764705883}
# Percentage of stop sequences exceeding 6 (weekday): 58.62%
# Percentage of stop sequences exceeding 6 (weekend): 51.72%
# {'ServiceNo': '196e', 'Weekday_Percentage_Exceed': 58.620689655172406, 'Weekend_Percentage_Exceed': 51.724137931034484}
# Percentage of stop sequences exceeding 6 (weekday): 26.09%
# Percentage of stop sequences exceeding 6 (weekend): 11.59%
# {'ServiceNo': '197', 'Weekday_Percentage_Exceed': 26.08695652173913, 'Weekend_Percentage_Exceed': 11.594202898550725}
# Percentage of stop sequences exceeding 6 (weekday): 20.45%
# Percentage of stop sequences exceeding 6 (weekend): 4.55%
# {'ServiceNo': '198', 'Weekday_Percentage_Exceed': 20.454545454545457, 'Weekend_Percentage_Exceed': 4.545454545454546}
# Percentage of stop sequences exceeding 6 (weekday): 92.31%
# Percentage of stop sequences exceeding 6 (weekend): 92.31%
# {'ServiceNo': '198A', 'Weekday_Percentage_Exceed': 92.3076923076923, 'Weekend_Percentage_Exceed': 92.3076923076923}
# Percentage of stop sequences exceeding 6 (weekday): 22.73%
# Percentage of stop sequences exceeding 6 (weekend): 6.82%
# {'ServiceNo': '20', 'Weekday_Percentage_Exceed': 22.727272727272727, 'Weekend_Percentage_Exceed': 6.8181818181818175}
# Percentage of stop sequences exceeding 6 (weekday): 22.22%
# Percentage of stop sequences exceeding 6 (weekend): 13.33%
# {'ServiceNo': '200', 'Weekday_Percentage_Exceed': 22.22222222222222, 'Weekend_Percentage_Exceed': 13.333333333333334}
# Percentage of stop sequences exceeding 6 (weekday): 78.26%
# Percentage of stop sequences exceeding 6 (weekend): 60.87%
# {'ServiceNo': '200A', 'Weekday_Percentage_Exceed': 78.26086956521739, 'Weekend_Percentage_Exceed': 60.86956521739131}
# Percentage of stop sequences exceeding 6 (weekday): 12.82%
# Percentage of stop sequences exceeding 6 (weekend): 10.26%
# {'ServiceNo': '201', 'Weekday_Percentage_Exceed': 12.82051282051282, 'Weekend_Percentage_Exceed': 10.256410256410255}
# Percentage of stop sequences exceeding 6 (weekday): 61.90%
# Percentage of stop sequences exceeding 6 (weekend): 28.57%
# {'ServiceNo': '20A', 'Weekday_Percentage_Exceed': 61.904761904761905, 'Weekend_Percentage_Exceed': 28.57142857142857}
# Percentage of stop sequences exceeding 6 (weekday): 39.13%
# Percentage of stop sequences exceeding 6 (weekend): 11.59%
# {'ServiceNo': '21', 'Weekday_Percentage_Exceed': 39.130434782608695, 'Weekend_Percentage_Exceed': 11.594202898550725}
# Percentage of stop sequences exceeding 6 (weekday): 77.78%
# Percentage of stop sequences exceeding 6 (weekend): 77.78%
# {'ServiceNo': '21A', 'Weekday_Percentage_Exceed': 77.77777777777779, 'Weekend_Percentage_Exceed': 77.77777777777779}
# Percentage of stop sequences exceeding 6 (weekday): 17.65%
# Percentage of stop sequences exceeding 6 (weekend): 5.88%
# {'ServiceNo': '22', 'Weekday_Percentage_Exceed': 17.647058823529413, 'Weekend_Percentage_Exceed': 5.88235294117647}
# Percentage of stop sequences exceeding 6 (weekday): 16.67%
# Percentage of stop sequences exceeding 6 (weekend): 3.33%
# {'ServiceNo': '222', 'Weekday_Percentage_Exceed': 16.666666666666664, 'Weekend_Percentage_Exceed': 3.3333333333333335}
# Percentage of stop sequences exceeding 6 (weekday): 90.91%
# Percentage of stop sequences exceeding 6 (weekend): 90.91%
# {'ServiceNo': '222A', 'Weekday_Percentage_Exceed': 90.9090909090909, 'Weekend_Percentage_Exceed': 90.9090909090909}
# Percentage of stop sequences exceeding 6 (weekday): 90.00%
# Percentage of stop sequences exceeding 6 (weekend): 60.00%
# {'ServiceNo': '222B', 'Weekday_Percentage_Exceed': 90.0, 'Weekend_Percentage_Exceed': 60.0}
# Percentage of stop sequences exceeding 6 (weekday): 9.09%
# Percentage of stop sequences exceeding 6 (weekend): 9.09%
# {'ServiceNo': '225G', 'Weekday_Percentage_Exceed': 9.090909090909092, 'Weekend_Percentage_Exceed': 9.090909090909092}
# Percentage of stop sequences exceeding 6 (weekday): 0.00%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '225W', 'Weekday_Percentage_Exceed': 0.0, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 20.00%
# Percentage of stop sequences exceeding 6 (weekend): 6.67%
# {'ServiceNo': '228', 'Weekday_Percentage_Exceed': 20.0, 'Weekend_Percentage_Exceed': 6.666666666666667}
# Percentage of stop sequences exceeding 6 (weekday): 29.17%
# Percentage of stop sequences exceeding 6 (weekend): 4.17%
# {'ServiceNo': '229', 'Weekday_Percentage_Exceed': 29.166666666666668, 'Weekend_Percentage_Exceed': 4.166666666666666}
# Percentage of stop sequences exceeding 6 (weekday): 17.78%
# Percentage of stop sequences exceeding 6 (weekend): 6.67%
# {'ServiceNo': '23', 'Weekday_Percentage_Exceed': 17.77777777777778, 'Weekend_Percentage_Exceed': 6.666666666666667}
# Percentage of stop sequences exceeding 6 (weekday): 8.33%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '230', 'Weekday_Percentage_Exceed': 8.333333333333332, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 27.78%
# Percentage of stop sequences exceeding 6 (weekend): 11.11%
# {'ServiceNo': '231', 'Weekday_Percentage_Exceed': 27.77777777777778, 'Weekend_Percentage_Exceed': 11.11111111111111}
# Percentage of stop sequences exceeding 6 (weekday): 5.00%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '232', 'Weekday_Percentage_Exceed': 5.0, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 8.00%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '235', 'Weekday_Percentage_Exceed': 8.0, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 0.00%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '238', 'Weekday_Percentage_Exceed': 0.0, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 26.21%
# Percentage of stop sequences exceeding 6 (weekend): 8.74%
# {'ServiceNo': '24', 'Weekday_Percentage_Exceed': 26.21359223300971, 'Weekend_Percentage_Exceed': 8.737864077669903}
# Percentage of stop sequences exceeding 6 (weekday): 9.09%
# Percentage of stop sequences exceeding 6 (weekend): 6.82%
# {'ServiceNo': '25', 'Weekday_Percentage_Exceed': 9.090909090909092, 'Weekend_Percentage_Exceed': 6.8181818181818175}
# Percentage of stop sequences exceeding 6 (weekday): 29.73%
# Percentage of stop sequences exceeding 6 (weekend): 5.41%
# {'ServiceNo': '26', 'Weekday_Percentage_Exceed': 29.72972972972973, 'Weekend_Percentage_Exceed': 5.405405405405405}
# Percentage of stop sequences exceeding 6 (weekday): 14.29%
# Percentage of stop sequences exceeding 6 (weekend): 7.14%
# {'ServiceNo': '261', 'Weekday_Percentage_Exceed': 14.285714285714285, 'Weekend_Percentage_Exceed': 7.142857142857142}
# Percentage of stop sequences exceeding 6 (weekday): 33.33%
# Percentage of stop sequences exceeding 6 (weekend): 4.17%
# {'ServiceNo': '262', 'Weekday_Percentage_Exceed': 33.33333333333333, 'Weekend_Percentage_Exceed': 4.166666666666666}
# Percentage of stop sequences exceeding 6 (weekday): 16.67%
# Percentage of stop sequences exceeding 6 (weekend): 7.14%
# {'ServiceNo': '265', 'Weekday_Percentage_Exceed': 16.666666666666664, 'Weekend_Percentage_Exceed': 7.142857142857142}
# Percentage of stop sequences exceeding 6 (weekday): 27.08%
# Percentage of stop sequences exceeding 6 (weekend): 6.25%
# {'ServiceNo': '268', 'Weekday_Percentage_Exceed': 27.083333333333332, 'Weekend_Percentage_Exceed': 6.25}
# Percentage of stop sequences exceeding 6 (weekday): 76.92%
# Percentage of stop sequences exceeding 6 (weekend): 57.69%
# {'ServiceNo': '268A', 'Weekday_Percentage_Exceed': 76.92307692307693, 'Weekend_Percentage_Exceed': 57.692307692307686}
# Percentage of stop sequences exceeding 6 (weekday): 90.91%
# Percentage of stop sequences exceeding 6 (weekend): 81.82%
# {'ServiceNo': '268B', 'Weekday_Percentage_Exceed': 90.9090909090909, 'Weekend_Percentage_Exceed': 81.81818181818183}
# Percentage of stop sequences exceeding 6 (weekday): 90.91%
# Percentage of stop sequences exceeding 6 (weekend): 90.91%
# {'ServiceNo': '268C', 'Weekday_Percentage_Exceed': 90.9090909090909, 'Weekend_Percentage_Exceed': 90.9090909090909}
# Percentage of stop sequences exceeding 6 (weekday): 31.82%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '269', 'Weekday_Percentage_Exceed': 31.818181818181817, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 66.67%
# Percentage of stop sequences exceeding 6 (weekend): 41.67%
# {'ServiceNo': '269A', 'Weekday_Percentage_Exceed': 66.66666666666666, 'Weekend_Percentage_Exceed': 41.66666666666667}
# Percentage of stop sequences exceeding 6 (weekday): 14.04%
# Percentage of stop sequences exceeding 6 (weekend): 3.51%
# {'ServiceNo': '27', 'Weekday_Percentage_Exceed': 14.035087719298245, 'Weekend_Percentage_Exceed': 3.508771929824561}
# Percentage of stop sequences exceeding 6 (weekday): 14.29%
# Percentage of stop sequences exceeding 6 (weekend): 7.14%
# {'ServiceNo': '272', 'Weekday_Percentage_Exceed': 14.285714285714285, 'Weekend_Percentage_Exceed': 7.142857142857142}
# Percentage of stop sequences exceeding 6 (weekday): 0.00%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '273', 'Weekday_Percentage_Exceed': 0.0, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 66.67%
# Percentage of stop sequences exceeding 6 (weekend): 33.33%
# {'ServiceNo': '27A', 'Weekday_Percentage_Exceed': 66.66666666666666, 'Weekend_Percentage_Exceed': 33.33333333333333}
# Percentage of stop sequences exceeding 6 (weekday): 33.90%
# Percentage of stop sequences exceeding 6 (weekend): 10.17%
# {'ServiceNo': '28', 'Weekday_Percentage_Exceed': 33.89830508474576, 'Weekend_Percentage_Exceed': 10.16949152542373}
# Percentage of stop sequences exceeding 6 (weekday): 12.96%
# Percentage of stop sequences exceeding 6 (weekend): 7.41%
# {'ServiceNo': '29', 'Weekday_Percentage_Exceed': 12.962962962962962, 'Weekend_Percentage_Exceed': 7.4074074074074066}
# Percentage of stop sequences exceeding 6 (weekday): 6.90%
# Percentage of stop sequences exceeding 6 (weekend): 3.45%
# {'ServiceNo': '291', 'Weekday_Percentage_Exceed': 6.896551724137931, 'Weekend_Percentage_Exceed': 3.4482758620689653}
# Percentage of stop sequences exceeding 6 (weekday): 28.57%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '292', 'Weekday_Percentage_Exceed': 28.57142857142857, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 9.76%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# ...
# Percentage of stop sequences exceeding 6 (weekday): 15.38%
# Percentage of stop sequences exceeding 6 (weekend): 3.85%
# {'ServiceNo': '334', 'Weekday_Percentage_Exceed': 15.384615384615385, 'Weekend_Percentage_Exceed': 3.8461538461538463}
# Percentage of stop sequences exceeding 6 (weekday): 12.90%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '335', 'Weekday_Percentage_Exceed': 12.903225806451612, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 13.16%
# Percentage of stop sequences exceeding 6 (weekend): 5.26%
# {'ServiceNo': '41', 'Weekday_Percentage_Exceed': 13.157894736842104, 'Weekend_Percentage_Exceed': 5.263157894736842}
# Percentage of stop sequences exceeding 6 (weekday): 17.65%
# Percentage of stop sequences exceeding 6 (weekend): 7.84%
# {'ServiceNo': '49', 'Weekday_Percentage_Exceed': 17.647058823529413, 'Weekend_Percentage_Exceed': 7.8431372549019605}
# Percentage of stop sequences exceeding 6 (weekday): 73.33%
# Percentage of stop sequences exceeding 6 (weekend): 60.00%
# {'ServiceNo': '651', 'Weekday_Percentage_Exceed': 73.33333333333333, 'Weekend_Percentage_Exceed': 60.0}
# Percentage of stop sequences exceeding 6 (weekday): 80.00%
# Percentage of stop sequences exceeding 6 (weekend): 75.00%
# {'ServiceNo': '653', 'Weekday_Percentage_Exceed': 80.0, 'Weekend_Percentage_Exceed': 75.0}
# Percentage of stop sequences exceeding 6 (weekday): 82.35%
# Percentage of stop sequences exceeding 6 (weekend): 70.59%
# {'ServiceNo': '656', 'Weekday_Percentage_Exceed': 82.35294117647058, 'Weekend_Percentage_Exceed': 70.58823529411765}
# Percentage of stop sequences exceeding 6 (weekday): 83.33%
# Percentage of stop sequences exceeding 6 (weekend): 83.33%
# {'ServiceNo': '657', 'Weekday_Percentage_Exceed': 83.33333333333334, 'Weekend_Percentage_Exceed': 83.33333333333334}
# Percentage of stop sequences exceeding 6 (weekday): 13.64%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '66', 'Weekday_Percentage_Exceed': 13.636363636363635, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 76.19%
# Percentage of stop sequences exceeding 6 (weekend): 76.19%
# {'ServiceNo': '663', 'Weekday_Percentage_Exceed': 76.19047619047619, 'Weekend_Percentage_Exceed': 76.19047619047619}
# Percentage of stop sequences exceeding 6 (weekday): 70.00%
# Percentage of stop sequences exceeding 6 (weekend): 65.00%
# {'ServiceNo': '670', 'Weekday_Percentage_Exceed': 70.0, 'Weekend_Percentage_Exceed': 65.0}
# Percentage of stop sequences exceeding 6 (weekday): 17.39%
# Percentage of stop sequences exceeding 6 (weekend): 10.87%
# {'ServiceNo': '77', 'Weekday_Percentage_Exceed': 17.391304347826086, 'Weekend_Percentage_Exceed': 10.869565217391305}
# Percentage of stop sequences exceeding 6 (weekday): 6.90%
# Percentage of stop sequences exceeding 6 (weekend): 3.45%
# {'ServiceNo': '78', 'Weekday_Percentage_Exceed': 6.896551724137931, 'Weekend_Percentage_Exceed': 3.4482758620689653}
# Percentage of stop sequences exceeding 6 (weekday): 62.50%
# Percentage of stop sequences exceeding 6 (weekend): 50.00%
# {'ServiceNo': '78A', 'Weekday_Percentage_Exceed': 62.5, 'Weekend_Percentage_Exceed': 50.0}
# Percentage of stop sequences exceeding 6 (weekday): 5.26%
# Percentage of stop sequences exceeding 6 (weekend): 1.75%
# {'ServiceNo': '79', 'Weekday_Percentage_Exceed': 5.263157894736842, 'Weekend_Percentage_Exceed': 1.7543859649122806}
# Percentage of stop sequences exceeding 6 (weekday): 60.71%
# Percentage of stop sequences exceeding 6 (weekend): 42.86%
# {'ServiceNo': '79T', 'Weekday_Percentage_Exceed': 60.71428571428571, 'Weekend_Percentage_Exceed': 42.857142857142854}
# Percentage of stop sequences exceeding 6 (weekday): 14.29%
# Percentage of stop sequences exceeding 6 (weekend): 4.76%
# {'ServiceNo': '801', 'Weekday_Percentage_Exceed': 14.285714285714285, 'Weekend_Percentage_Exceed': 4.761904761904762}
# Percentage of stop sequences exceeding 6 (weekday): 40.00%
# Percentage of stop sequences exceeding 6 (weekend): 6.67%
# {'ServiceNo': '825', 'Weekday_Percentage_Exceed': 40.0, 'Weekend_Percentage_Exceed': 6.666666666666667}
# Percentage of stop sequences exceeding 6 (weekday): 37.21%
# Percentage of stop sequences exceeding 6 (weekend): 11.63%
# {'ServiceNo': '853', 'Weekday_Percentage_Exceed': 37.2093023255814, 'Weekend_Percentage_Exceed': 11.627906976744185}
# Percentage of stop sequences exceeding 6 (weekday): 36.62%
# Percentage of stop sequences exceeding 6 (weekend): 11.27%
# {'ServiceNo': '853M', 'Weekday_Percentage_Exceed': 36.61971830985916, 'Weekend_Percentage_Exceed': 11.267605633802818}
# Percentage of stop sequences exceeding 6 (weekday): 9.80%
# Percentage of stop sequences exceeding 6 (weekend): 3.92%
# {'ServiceNo': '854', 'Weekday_Percentage_Exceed': 9.803921568627452, 'Weekend_Percentage_Exceed': 3.9215686274509802}
# Percentage of stop sequences exceeding 6 (weekday): 95.83%
# Percentage of stop sequences exceeding 6 (weekend): 91.67%
# {'ServiceNo': '854e', 'Weekday_Percentage_Exceed': 95.83333333333334, 'Weekend_Percentage_Exceed': 91.66666666666666}
# Percentage of stop sequences exceeding 6 (weekday): 25.93%
# Percentage of stop sequences exceeding 6 (weekend): 7.41%
# {'ServiceNo': '855', 'Weekday_Percentage_Exceed': 25.925925925925924, 'Weekend_Percentage_Exceed': 7.4074074074074066}
# Percentage of stop sequences exceeding 6 (weekday): 10.81%
# Percentage of stop sequences exceeding 6 (weekend): 8.11%
# {'ServiceNo': '856', 'Weekday_Percentage_Exceed': 10.81081081081081, 'Weekend_Percentage_Exceed': 8.108108108108109}
# Percentage of stop sequences exceeding 6 (weekday): 85.71%
# Percentage of stop sequences exceeding 6 (weekend): 85.71%
# {'ServiceNo': '856A', 'Weekday_Percentage_Exceed': 85.71428571428571, 'Weekend_Percentage_Exceed': 85.71428571428571}
# Percentage of stop sequences exceeding 6 (weekday): 56.67%
# Percentage of stop sequences exceeding 6 (weekend): 30.00%
# {'ServiceNo': '856B', 'Weekday_Percentage_Exceed': 56.666666666666664, 'Weekend_Percentage_Exceed': 30.0}
# Percentage of stop sequences exceeding 6 (weekday): 15.62%
# Percentage of stop sequences exceeding 6 (weekend): 3.12%
# {'ServiceNo': '857', 'Weekday_Percentage_Exceed': 15.625, 'Weekend_Percentage_Exceed': 3.125}
# Percentage of stop sequences exceeding 6 (weekday): 80.00%
# Percentage of stop sequences exceeding 6 (weekend): 40.00%
# {'ServiceNo': '857A', 'Weekday_Percentage_Exceed': 80.0, 'Weekend_Percentage_Exceed': 40.0}
# Percentage of stop sequences exceeding 6 (weekday): 87.10%
# Percentage of stop sequences exceeding 6 (weekend): 70.97%
# {'ServiceNo': '857B', 'Weekday_Percentage_Exceed': 87.09677419354838, 'Weekend_Percentage_Exceed': 70.96774193548387}
# Percentage of stop sequences exceeding 6 (weekday): 14.67%
# Percentage of stop sequences exceeding 6 (weekend): 5.33%
# {'ServiceNo': '858', 'Weekday_Percentage_Exceed': 14.666666666666666, 'Weekend_Percentage_Exceed': 5.333333333333334}
# Percentage of stop sequences exceeding 6 (weekday): 91.67%
# Percentage of stop sequences exceeding 6 (weekend): 79.17%
# {'ServiceNo': '858A', 'Weekday_Percentage_Exceed': 91.66666666666666, 'Weekend_Percentage_Exceed': 79.16666666666666}
# Percentage of stop sequences exceeding 6 (weekday): 90.91%
# Percentage of stop sequences exceeding 6 (weekend): 81.82%
# {'ServiceNo': '858B', 'Weekday_Percentage_Exceed': 90.9090909090909, 'Weekend_Percentage_Exceed': 81.81818181818183}
# Percentage of stop sequences exceeding 6 (weekday): 20.00%
# Percentage of stop sequences exceeding 6 (weekend): 4.00%
# {'ServiceNo': '859', 'Weekday_Percentage_Exceed': 20.0, 'Weekend_Percentage_Exceed': 4.0}
# Percentage of stop sequences exceeding 6 (weekday): 28.57%
# Percentage of stop sequences exceeding 6 (weekend): 7.14%
# {'ServiceNo': '859A', 'Weekday_Percentage_Exceed': 28.57142857142857, 'Weekend_Percentage_Exceed': 7.142857142857142}
# Percentage of stop sequences exceeding 6 (weekday): 21.43%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '859B', 'Weekday_Percentage_Exceed': 21.428571428571427, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 92.31%
# Percentage of stop sequences exceeding 6 (weekend): 88.46%
# {'ServiceNo': '859T', 'Weekday_Percentage_Exceed': 92.3076923076923, 'Weekend_Percentage_Exceed': 88.46153846153845}
# Percentage of stop sequences exceeding 6 (weekday): 10.71%
# Percentage of stop sequences exceeding 6 (weekend): 5.36%
# {'ServiceNo': '861', 'Weekday_Percentage_Exceed': 10.714285714285714, 'Weekend_Percentage_Exceed': 5.357142857142857}
# Percentage of stop sequences exceeding 6 (weekday): 68.97%
# Percentage of stop sequences exceeding 6 (weekend): 51.72%
# {'ServiceNo': '861A', 'Weekday_Percentage_Exceed': 68.96551724137932, 'Weekend_Percentage_Exceed': 51.724137931034484}
# Percentage of stop sequences exceeding 6 (weekday): 25.00%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '870', 'Weekday_Percentage_Exceed': 25.0, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 19.15%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '871', 'Weekday_Percentage_Exceed': 19.148936170212767, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 16.67%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '882', 'Weekday_Percentage_Exceed': 16.666666666666664, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 85.71%
# Percentage of stop sequences exceeding 6 (weekend): 71.43%
# {'ServiceNo': '882A', 'Weekday_Percentage_Exceed': 85.71428571428571, 'Weekend_Percentage_Exceed': 71.42857142857143}
# Percentage of stop sequences exceeding 6 (weekday): 21.21%
# Percentage of stop sequences exceeding 6 (weekend): 12.12%
# {'ServiceNo': '883', 'Weekday_Percentage_Exceed': 21.21212121212121, 'Weekend_Percentage_Exceed': 12.121212121212121}
# Percentage of stop sequences exceeding 6 (weekday): 81.82%
# Percentage of stop sequences exceeding 6 (weekend): 81.82%
# {'ServiceNo': '883B', 'Weekday_Percentage_Exceed': 81.81818181818183, 'Weekend_Percentage_Exceed': 81.81818181818183}
# Percentage of stop sequences exceeding 6 (weekday): 60.61%
# Percentage of stop sequences exceeding 6 (weekend): 42.42%
# {'ServiceNo': '883M', 'Weekday_Percentage_Exceed': 60.60606060606061, 'Weekend_Percentage_Exceed': 42.42424242424242}
# Percentage of stop sequences exceeding 6 (weekday): 5.26%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '941', 'Weekday_Percentage_Exceed': 5.263157894736842, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 21.05%
# Percentage of stop sequences exceeding 6 (weekend): 10.53%
# {'ServiceNo': '945', 'Weekday_Percentage_Exceed': 21.052631578947366, 'Weekend_Percentage_Exceed': 10.526315789473683}
# Percentage of stop sequences exceeding 6 (weekday): 14.29%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '947', 'Weekday_Percentage_Exceed': 14.285714285714285, 'Weekend_Percentage_Exceed': 0.0}
# Percentage of stop sequences exceeding 6 (weekday): 26.67%
# Percentage of stop sequences exceeding 6 (weekend): 6.67%
# {'ServiceNo': '96', 'Weekday_Percentage_Exceed': 26.666666666666668, 'Weekend_Percentage_Exceed': 6.666666666666667}
# Percentage of stop sequences exceeding 6 (weekday): 24.49%
# Percentage of stop sequences exceeding 6 (weekend): 10.20%
# {'ServiceNo': '963', 'Weekday_Percentage_Exceed': 24.489795918367346, 'Weekend_Percentage_Exceed': 10.204081632653061}
# Percentage of stop sequences exceeding 6 (weekday): 95.45%
# Percentage of stop sequences exceeding 6 (weekend): 90.91%
# {'ServiceNo': '963e', 'Weekday_Percentage_Exceed': 95.45454545454545, 'Weekend_Percentage_Exceed': 90.9090909090909}
# Percentage of stop sequences exceeding 6 (weekday): 15.09%
# Percentage of stop sequences exceeding 6 (weekend): 5.66%
# {'ServiceNo': '965', 'Weekday_Percentage_Exceed': 15.09433962264151, 'Weekend_Percentage_Exceed': 5.660377358490567}
# Percentage of stop sequences exceeding 6 (weekday): 93.33%
# Percentage of stop sequences exceeding 6 (weekend): 73.33%
# {'ServiceNo': '965A', 'Weekday_Percentage_Exceed': 93.33333333333333, 'Weekend_Percentage_Exceed': 73.33333333333333}
# Percentage of stop sequences exceeding 6 (weekday): 88.89%
# Percentage of stop sequences exceeding 6 (weekend): 70.37%
# {'ServiceNo': '965T', 'Weekday_Percentage_Exceed': 88.88888888888889, 'Weekend_Percentage_Exceed': 70.37037037037037}
# Percentage of stop sequences exceeding 6 (weekday): 25.49%
# Percentage of stop sequences exceeding 6 (weekend): 5.88%
# {'ServiceNo': '966', 'Weekday_Percentage_Exceed': 25.49019607843137, 'Weekend_Percentage_Exceed': 5.88235294117647}
# Percentage of stop sequences exceeding 6 (weekday): 96.30%
# Percentage of stop sequences exceeding 6 (weekend): 92.59%
# {'ServiceNo': '966A', 'Weekday_Percentage_Exceed': 96.29629629629629, 'Weekend_Percentage_Exceed': 92.5925925925926}
# Percentage of stop sequences exceeding 6 (weekday): 20.69%
# Percentage of stop sequences exceeding 6 (weekend): 10.34%
# {'ServiceNo': '969', 'Weekday_Percentage_Exceed': 20.689655172413794, 'Weekend_Percentage_Exceed': 10.344827586206897}
# Percentage of stop sequences exceeding 6 (weekday): 80.00%
# Percentage of stop sequences exceeding 6 (weekend): 86.67%
# {'ServiceNo': '969A', 'Weekday_Percentage_Exceed': 80.0, 'Weekend_Percentage_Exceed': 86.66666666666667}
# Percentage of stop sequences exceeding 6 (weekday): 40.00%
# Percentage of stop sequences exceeding 6 (weekend): 40.00%
# {'ServiceNo': '96A', 'Weekday_Percentage_Exceed': 40.0, 'Weekend_Percentage_Exceed': 40.0}
# Percentage of stop sequences exceeding 6 (weekday): 50.00%
# Percentage of stop sequences exceeding 6 (weekend): 37.50%
# {'ServiceNo': '96B', 'Weekday_Percentage_Exceed': 50.0, 'Weekend_Percentage_Exceed': 37.5}
# Percentage of stop sequences exceeding 6 (weekday): 18.42%
# Percentage of stop sequences exceeding 6 (weekend): 2.63%
# {'ServiceNo': '97', 'Weekday_Percentage_Exceed': 18.421052631578945, 'Weekend_Percentage_Exceed': 2.631578947368421}
# Percentage of stop sequences exceeding 6 (weekday): 92.00%
# Percentage of stop sequences exceeding 6 (weekend): 88.00%
# {'ServiceNo': '97e', 'Weekday_Percentage_Exceed': 92.0, 'Weekend_Percentage_Exceed': 88.0}
# Percentage of stop sequences exceeding 6 (weekday): 18.84%
# Percentage of stop sequences exceeding 6 (weekend): 4.35%
# {'ServiceNo': '98', 'Weekday_Percentage_Exceed': 18.84057971014493, 'Weekend_Percentage_Exceed': 4.3478260869565215}
# Percentage of stop sequences exceeding 6 (weekday): 20.31%
# Percentage of stop sequences exceeding 6 (weekend): 6.25%
# {'ServiceNo': '980', 'Weekday_Percentage_Exceed': 20.3125, 'Weekend_Percentage_Exceed': 6.25}
# Percentage of stop sequences exceeding 6 (weekday): 28.57%
# Percentage of stop sequences exceeding 6 (weekend): 14.29%
# {'ServiceNo': '981', 'Weekday_Percentage_Exceed': 28.57142857142857, 'Weekend_Percentage_Exceed': 14.285714285714285}
# Percentage of stop sequences exceeding 6 (weekday): 81.82%
# Percentage of stop sequences exceeding 6 (weekend): 54.55%
# {'ServiceNo': '98A', 'Weekday_Percentage_Exceed': 81.81818181818183, 'Weekend_Percentage_Exceed': 54.54545454545454}
# Percentage of stop sequences exceeding 6 (weekday): 70.37%
# Percentage of stop sequences exceeding 6 (weekend): 51.85%
# {'ServiceNo': '98B', 'Weekday_Percentage_Exceed': 70.37037037037037, 'Weekend_Percentage_Exceed': 51.85185185185185}
# Percentage of stop sequences exceeding 6 (weekday): 81.25%
# Percentage of stop sequences exceeding 6 (weekend): 62.50%
# {'ServiceNo': '98M', 'Weekday_Percentage_Exceed': 81.25, 'Weekend_Percentage_Exceed': 62.5}
# Percentage of stop sequences exceeding 6 (weekday): 17.86%
# Percentage of stop sequences exceeding 6 (weekend): 7.14%
# {'ServiceNo': '990', 'Weekday_Percentage_Exceed': 17.857142857142858, 'Weekend_Percentage_Exceed': 7.142857142857142}
# Percentage of stop sequences exceeding 6 (weekday): 7.14%
# Percentage of stop sequences exceeding 6 (weekend): 0.00%
# {'ServiceNo': '992', 'Weekday_Percentage_Exceed': 7.142857142857142, 'Weekend_Percentage_Exceed': 0.0}

# %%
# inspect ridership_percentage_df
ridership_percentage_df.head()

ridership_analysis_final = ridership_percentage_df.sort_values(by=['Weekday_Percentage_Exceed', 'Weekend_Percentage_Exceed'], ascending=[False, False])
ridership_analysis_final.head()
# Out:
#     ServiceNo  Weekday_Percentage_Exceed  Weekend_Percentage_Exceed
# 316      811T                  97.674419                  88.372093
# 300        7A                  97.142857                  94.285714
# 154      174e                  97.058824                  94.117647
# 163      196A                  97.058824                  85.294118
# 31         3A                  96.428571                  85.714286

# %%
ridership_analysis_final.to_csv('../data/analysis/ridership_analysis_final.csv', index=False)
