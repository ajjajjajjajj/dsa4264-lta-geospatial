# %% [markdown]
# ## Data Exploration
# ### Data from LTA Datamall and Land Transport Guru (https://landtransportguru.net/train/tel/)

# %%
import geopandas
import re
import pandas as pd
import json
import folium
import requests
import time
from tqdm import tqdm
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None
import seaborn as sns

# %%
ridership = pd.read_csv('dsa4264-lta-geospatial/data/monthly_ave_daily_pt_ridership.csv')
ridership.head()
# Out:
#     month        mode  ridership
# 0  Jan-19         MRT    3462000
# 1  Jan-19         LRT     218000
# 2  Jan-19  Public Bus    4250000
# 3  Feb-19         MRT    3248000
# 4  Feb-19         LRT     206000

# %%
# Filter the data for the last 2 years
ridership['month'] = pd.to_datetime(ridership['month'], format='%b-%y')
last_5_years = ridership['month'].max() - pd.DateOffset(years=1)
ridership_last_5_years = ridership[ridership['month'] >= last_5_years]
ridership_last_5_years = ridership_last_5_years[ridership_last_5_years['mode'] == 'Public Bus']

# Group the data by 'month' and 'mode' to calculate the total ridership per mode
ridership_trends = ridership_last_5_years.groupby(['month', 'mode']).sum().reset_index()

# Create a line plot to visualize ridership trends
plt.figure(figsize=(10, 6))
sns.lineplot(data=ridership_trends, x='month', y='ridership', hue='mode', marker='o')

# Customize plot labels and title
plt.title('Monthly Ridership Trend', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Ridership', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Mode of Transport')
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Bus Routes

# %%
def call_busroutes_api():

    url = "https://datamall2.mytransport.sg/ltaodataservice/BusRoutes"

    payload = {}
    headers = {
    'AccountKey': '',
    'Accept': 'application/json'
    }

    response = requests.request("GET", url, headers=headers, data=payload)
    return response.json()['value']

bus_routes = call_busroutes_api()

print(bus_routes)
# Out:
# {'odata.metadata': 'http://datamall2.mytransport.sg/ltaodataservice/$metadataBusRoutes', 'value': [{'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 1, 'BusStopCode': '75009', 'Distance': 0, 'WD_FirstBus': '0500', 'WD_LastBus': '2300', 'SAT_FirstBus': '0500', 'SAT_LastBus': '2300', 'SUN_FirstBus': '0500', 'SUN_LastBus': '2300'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 2, 'BusStopCode': '76059', 'Distance': 0.6, 'WD_FirstBus': '0502', 'WD_LastBus': '2302', 'SAT_FirstBus': '0502', 'SAT_LastBus': '2302', 'SUN_FirstBus': '0502', 'SUN_LastBus': '2302'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 3, 'BusStopCode': '76069', 'Distance': 1.1, 'WD_FirstBus': '0504', 'WD_LastBus': '2304', 'SAT_FirstBus': '0504', 'SAT_LastBus': '2304', 'SUN_FirstBus': '0503', 'SUN_LastBus': '2304'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 4, 'BusStopCode': '96289', 'Distance': 2.3, 'WD_FirstBus': '0508', 'WD_LastBus': '2308', 'SAT_FirstBus': '0508', 'SAT_LastBus': '2309', 'SUN_FirstBus': '0507', 'SUN_LastBus': '2308'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 5, 'BusStopCode': '96109', 'Distance': 2.7, 'WD_FirstBus': '0509', 'WD_LastBus': '2310', 'SAT_FirstBus': '0509', 'SAT_LastBus': '2311', 'SUN_FirstBus': '0508', 'SUN_LastBus': '2309'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 6, 'BusStopCode': '85079', 'Distance': 3.3, 'WD_FirstBus': '0511', 'WD_LastBus': '2312', 'SAT_FirstBus': '0511', 'SAT_LastBus': '2313', 'SUN_FirstBus': '0510', 'SUN_LastBus': '2311'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 7, 'BusStopCode': '85089', 'Distance': 3.5, 'WD_FirstBus': '0512', 'WD_LastBus': '2313', 'SAT_FirstBus': '0512', 'SAT_LastBus': '2314', 'SUN_FirstBus': '0511', 'SUN_LastBus': '2312'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 8, 'BusStopCode': '85069', 'Distance': 3.8, 'WD_FirstBus': '0513', 'WD_LastBus': '2314', 'SAT_FirstBus': '0513', 'SAT_LastBus': '2315', 'SUN_FirstBus': '0512', 'SUN_LastBus': '2313'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 9, 'BusStopCode': '85059', 'Distance': 4.1, 'WD_FirstBus': '0514', 'WD_LastBus': '2315', 'SAT_FirstBus': '0514', 'SAT_LastBus': '2316', 'SUN_FirstBus': '0513', 'SUN_LastBus': '2314'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 10, 'BusStopCode': '85049', 'Distance': 4.5, 'WD_FirstBus': '0515', 'WD_LastBus': '2316', 'SAT_FirstBus': '0515', 'SAT_LastBus': '2317', 'SUN_FirstBus': '0514', 'SUN_LastBus': '2315'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 11, 'BusStopCode': '85039', 'Distance': 4.8, 'WD_FirstBus': '0517', 'WD_LastBus': '2317', 'SAT_FirstBus': '0517', 'SAT_LastBus': '2319', 'SUN_FirstBus': '0516', 'SUN_LastBus': '2317'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 12, 'BusStopCode': '85029', 'Distance': 5, 'WD_FirstBus': '0517', 'WD_LastBus': '2318', 'SAT_FirstBus': '0517', 'SAT_LastBus': '2319', 'SUN_FirstBus': '0516', 'SUN_LastBus': '2317'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 13, 'BusStopCode': '85019', 'Distance': 5.2, 'WD_FirstBus': '0518', 'WD_LastBus': '2318', 'SAT_FirstBus': '0518', 'SAT_LastBus': '2320', 'SUN_FirstBus': '0517', 'SUN_LastBus': '2318'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 14, 'BusStopCode': '94079', 'Distance': 5.5, 'WD_FirstBus': '0519', 'WD_LastBus': '2319', 'SAT_FirstBus': '0519', 'SAT_LastBus': '2321', 'SUN_FirstBus': '0518', 'SUN_LastBus': '2319'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'StopSequence': 15, 'BusStopCode': '94069', 'Distance': 6.1, 'WD_FirstBus': '0520', 'WD_LastBus': '2320', 'SAT_FirstBus': '0520', 'SAT_LastBus': '2322', 'SUN_FirstBus': '0519', 'SUN_LastBus': '2321'}, {'ServiceNo': '10', 'Operator': 'SBST', 'Direction': 1, 'St ...

# %% [markdown]
# #### Bus Stops

# %%
def call_busstops_api(data_variable):
    url = "https://datamall2.mytransport.sg/ltaodataservice/BusStops"

    payload = {}
    headers = {
    'AccountKey': '',
    'Accept': 'application/json'
    }

    response = requests.request("GET", url, headers=headers, data=payload)

    bus_stops = response.json()['value']
    return [stop[str(data_variable)] for stop in bus_stops]

bus_stop_codes = call_busstops_api('BusStopCode')
bus_stop_names = call_busstops_api('Description')
print(bus_stop_names)
# Out:
# ['Hotel Grand Pacific', "St. Joseph's Ch", 'Bras Basah Cplx', 'Opp Natl Lib', 'Bugis Cube', 'Bugis Stn Exit B', 'Queen St Ter', 'Opp Bugis Stn Exit C', 'Bugis Stn Exit A', 'Aft Bugis Stn Exit C', 'Stamford Pr Sch', 'Opp Stamford Pr Sch', 'Bugis Stn/Parkview Sq', 'Opp Blk 461', 'Blk 461', 'Bef Sultan Mque', 'Opp Textile Ctr', 'Sultan Plaza', 'Lavender Stn Exit B', 'Lavender Stn Exit A/ICA', 'Blk 8', 'Bef Crawford Bridge', 'Southbank', 'Opp Blk 4', 'Opp St. John HQ', 'St. John HQ', 'Opp Golden Mile Cplx', 'Golden Mile Cplx', 'Opp The Gateway', 'The Gateway', 'Opp Plaza Parkroyal', 'Plaza Parkroyal', 'Bugis Stn Exit D', 'Opp Duo Residences', 'Village Hotel Bugis', 'Aft Raffles Hotel', 'Esplanade Stn Exit F', 'Opp Shaw Twrs', 'Shaw Twrs', 'Aft Beach Rd', 'Bef Beach Rd', 'Aft Esplanade Stn Exit D', 'Raffles Hotel', 'The Float @ Marina Bay', 'The Esplanade', 'Promenade Stn/Pan Pacific', "Aft S'pore Flyer", 'Esplanade Bridge', 'Opp War Memorial Pk', 'Suntec Twr Two', 'Suntec Twr Three', 'Suntec Convention Ctr', 'Opp Suntec Convention Ctr', 'Aft Promenade Stn Exit C', 'Promenade Stn Exit B', 'Opp The Ritz-Carlton', 'Supreme Ct', 'Fullerton Sq', 'OUE Bayfront', 'Prudential Twr', 'Raffles Pl Stn Exit F', 'Telok Ayer Stn Exit A', 'One Raffles Quay', '80 Robinson Rd', 'Aft Capital Twr', 'UIC Bldg', 'Opp GB Bldg', 'Opp AXA Twr', 'Opp MAS Bldg', 'Hub Synergy Pt', 'Tanjong Pagar Stn Exit C', 'Shenton Way Ter', 'Mapletree Anson', 'Bef Marina Gdns Dr', 'Aft Marina Gdns Dr', 'Bef Gdns by the Bay', 'Aft Gdns by the Bay', 'GARDENS BY THE BAY STN EXIT 2', 'GARDENS BY THE BAY STN EXIT 1', 'Gdns by the Bay', 'The Sail', 'Marina Bay Financial Ctr', 'Opp Marina Sth Pier Stn', 'Marina Sth Pier Stn', 'Marina Bay Cruise Ctr', 'Marina Bay Sands Theatre', 'Bayfront Stn Exit B/MBS', 'Aft Bayfront Stn Exit E', 'Bayfront Stn Exit A', 'Downtown Stn Exit E', 'Marina Bay Stn', 'Shenton Way Stn Exit 3', 'Opp Downtown Stn', 'OPP BENCOOLEN STN EXIT B', 'BEF BENCOOLEN STN EXIT A', 'Capitol Bldg', 'SMU', 'Armenian Ch', 'Stamford Ct', 'Grand Pk City Hall', 'Cath Of The Good Shepherd', 'Aft Chijmes', 'City Hall Stn Exit B', 'Aft City Hall Stn Exit B', 'Aft Bras Basah Stn Exit A', 'Clarke Quay', 'Opp Clarke Quay', 'Clarke Quay Stn Exit E', 'Old Hill St Police Stn', 'High St Ctr', 'Opp Clarke Quay Stn', 'Opp The Treasury', 'Opp High St Ctr', 'Aft River Valley Rd', 'UE Sq', 'Opp UE Sq', 'BEF FORT CANNING STN', 'FORT CANNING STN EXIT B', "Bef Pearl'S Hill Terr", 'Chinatown Stn Exit C', 'Aft Duxton Plain Pk', 'Aft Chinatown Stn Exit D', 'Opp Hong Lim Pk', 'Boat Quay', 'New Bridge Ctr', 'Chinatown Stn Exit E', 'Hong Lim Pk', 'OUTRAM PK STN EXIT 4', 'Opp One Upp Pickering', 'Opp Hong Lim Cplx', 'Opp Sri Mariamman Tp', 'Opp Hong Lim Cplx', 'Bef The Pinnacle@Duxton', 'Opp Blk 333', 'OPP MAXWELL STN EXIT 3', 'MAXWELL STN EXIT 2', 'Opp Fairfield Meth Ch', 'OCBC Ctr', 'Tg Pagar Plaza', 'The Amara', 'Aft Craig Rd', 'Bef Craig Rd', 'Aft Tanjong Pagar Rd', 'Blk 1G', 'Maritime Hse', 'Opp Southpoint', 'Blk 16', 'Bef Cantonment Rd', 'Opp Customs Port Br HQ', 'Opp Fuji Xerox Twrs', 'OUTRAM PK STN EXIT 7', 'OUTRAM PK STN EXIT 1', 'The Landmark Condo', 'Blk 8', 'BEF OUTRAM FLYOVER', 'Blk 55', 'Aft Furama RiverFront', 'HAVELOCK STN EXIT 2', 'HAVELOCK STN EXIT 3', 'Grand Copthorne Hotel', 'Aft Blk 87', 'HAVELOCK STN EXIT 5', 'HAVELOCK STN EXIT 4', 'Hotel Miramar', 'Opp Hotel Miramar', 'Blk 2', 'River Pl Condo', 'Opp State Ct', 'Ctrl Sq', 'Peace Ctr', 'Selegie Ctr', 'Tekka Ctr', 'Broadway Hotel', 'Aft Farrer Pk Stn Exit G', 'Sri Vadapathira K Tp', 'Bef Tai Hoe Hotel', "Bef S'Goon Rd", 'Aft Kempas Rd', 'Aft Allenby Rd', 'Hoa Nam Bldg', "Aft King George's Ave", 'ARC 380', 'OPP ARC 380', 'Bef Kallang Bahru', 'Aft Kallang Bahru', 'Aft Kallang Rd', 'Aperia/Bef Kallang Rd', 'Opp Veerasamy Rd', "IBIS S'PORE ON BENCOOLEN", 'OPP NAFA CAMPUS 3', 'JLN BESAR STN EXIT A', 'Rochor Stn', 'Bef Rochor Stn Exit B', 'Fu Lu Shou Cplx', 'Bef Waterloo St', 'Aft Waterloo St', 'SUNSHINE PLAZA', 'Ch of Our Lady of Lo ...

# %% [markdown]
# #### Passenger Volume by Train Stations

# %%
# PASSENGER VOLUME BY TRAIN STATIONS DATA DOWNLOAD LINK
def call_pv_train_api():
  url = "https://datamall2.mytransport.sg/ltaodataservice/PV/Train"

  payload = {}
  headers = {
    'AccountKey': '',
    'Accept': 'application/json'
  }

  response = requests.request("GET", url, headers=headers, data=payload)

  return response.json()['value']

call_pv_train_api()
# Out:
# [{'Link': 'https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202408/transport_node_train_202408.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjELn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkcwRQIhAP7wXc0IrCAlq6G2oNk24BZ8SHE533x4unXJgl%2FS9qWvAiAJbPZ7MZnQcgD6ibDFF1gDs7kJC8NFWM7tcvCCjHeWOyrCBQgSEAQaDDM0MDY0NTM4MTMwNCIMjdTL%2FFNX%2Fge6SGY0Kp8F7btfEMWOr%2BhEn1qwjHRUypofMfyNTJyY7mP3bpFJ29rmLJI6%2B%2Fg5WIcFHx0yrQnWhCN5LzUhpOIdKneqMsgxtCdN8WXzuWmGx9aCbdfJerp2k1nU0QMYXJCvN%2BRzQM8JJm1kgCfkKudc%2FDySgOqZD6PbhaFYoDPHPVyH0z47IAJn7ARqAlBHg%2Fbv5c8RCG3ySRsVh7opVUX0CqN0sCMCmhN8o3jL1Ucjx2ft%2B80%2FJdk9BM1Uq6C23XELGau%2BfODyF6e%2Frw8cppnNsUwsv7dXRE7cv5%2FAktWUe%2FzcZxgsiUNitX05jxfC3Nhs4uLUu%2FzVGPO2%2FEDYlinp6FvMC522Y%2BqTwjnkl%2FFBUEh4i2P6DzwHQxIs64m7b66PMMKorrtVNBLUJ%2F7JQz2wBmfK%2BWNvvuA%2Ba%2BCzyEleUyKNSMh5b9Lw1FROikTCc9IFGlasWiHr9P71eSF1kWA8HmEC5bh80siNYJO%2BbZaO4Dv42LKN2TJchYMQ5PKa4L9RiV1ktpFwPOI9s6WxKny7XLp3inW5kOVq97%2B5gUSk9AF87Rl9F9vM4GD0%2BVlFhAYb3azzGkP63iiXyUR00oAc0NCRGv2MZCHLlQQzLCj2nwMAiJxKxVWUD7Oty4TpaN9nbmCFs0zrJaZ8fXwQuDPtP44PGat4A%2B4OPTF4AAo2g60bijRYd3yItX%2FIPpmkmCfirIRtIOrtE5W%2BQs9HeN%2FM18bL3K8DOlxHIgwgsc3LtknKQJRFmJF30qLSrgs14%2BJepkV8UrnfIOqu41Me6IJ8dCCBJsVJ%2BPeCHq7zqa7OuH9SpY15jtqR95p%2FQ1lEqoqNKO3Ql%2FEz6DE%2FzJKGESm1EHmFa6yaq8WJu9WVe8iqtLwxPPKqU0PhM7aJ1d9J69BAjEGu%2FTQw0aaJuAY6sQEqXAUwVcWfFXm%2FX2K7%2FM%2Fz%2FnfF8ckSv97yK%2F1MATDypo3wnNbFTBCiCfCbYULN%2BRiI2yGQkPKWMboPfVKq8pMw9n1O%2FJ6zdiN56YCq1r6EVi0cd6Fm6cXoIEKbyCEjhu052pujxid%2Bi0lap%2F0HtJIWLR2YT3pOjoWoE%2B4TQWKw3T5ULbee3gUsj3mCPzlWOlPTd8CUwkRL%2FVb3q2C4hPkjolG84kpb8mErV8E57Cesntk%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241006T094721Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAU6UAMAS4CGDQKLOL%2F20241006%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=ed674d24b29d789ee5f64b4d3b43d035b41434fdb9eb34033cdf6cdfe86a0f66'}]

# %%
pv_train = pd.read_csv('dsa4264-lta-geospatial/data/transport_node_train_202408.csv')
pv_train_tel = pv_train[pv_train['PT_CODE'].str.startswith('TE')]
pv_train_tel.head()
# Out:
#    YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE PT_CODE  \
# 3     2024-08  WEEKENDS/HOLIDAY             20   TRAIN    TE23
# 5     2024-08           WEEKDAY             12   TRAIN     TE6
# 11    2024-08           WEEKDAY             21   TRAIN     TE1
# 15    2024-08  WEEKENDS/HOLIDAY             16   TRAIN    TE28
# 18    2024-08           WEEKDAY             15   TRAIN    TE13
#
#     TOTAL_TAP_IN_VOLUME  TOTAL_TAP_OUT_VOLUME
# 3                  1935                  1733
# 5                  9828                  5968
# 11                 5148                  3271
# 15                 2094                  3083
# 18                 5383                  5207

# %% [markdown]
# #### Passenger Volume by Bus Stops

# %%
# PASSENGER VOLUME BY BUS STOPS DATA DOWNLOAD LINK

def call_pv_bus_api(date):
  url = "https://datamall2.mytransport.sg/ltaodataservice/PV/Bus?Date=" + date

  payload = {}
  headers = {
    'AccountKey': '',
    'Accept': 'application/json'
  }

  response = requests.request("GET", url, headers=headers, data=payload)

  return response.json()

call_pv_bus_api('202408')
# Out:
# {'fault': {'faultstring': 'Rate limit quota violation. Quota limit  exceeded. Identifier : dEA2syClTBi67NLWnPBN0g==',
#   'detail': {'errorcode': 'policies.ratelimit.QuotaViolation'}}}

# %%
# List of CSV file paths
csv_files = ['dsa4264-lta-geospatial/data/transport_node_bus_202408.csv', 'dsa4264-lta-geospatial/data/transport_node_bus_202407.csv', 'dsa4264-lta-geospatial/data/transport_node_bus_202406.csv']

# Read and combine all CSVs into one DataFrame
df_list = [pd.read_csv(file) for file in csv_files]
pv_bus = pd.concat(df_list, ignore_index=True)
#print(pv_bus.head())
# Out:
#       YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  PT_CODE  \
# 4584     2024-08  WEEKENDS/HOLIDAY           14.0     BUS    47201
# 7187     2024-08           WEEKDAY           14.0     BUS    47201
# 8878     2024-08           WEEKDAY            7.0     BUS    47201
# 9256     2024-08  WEEKENDS/HOLIDAY            0.0     BUS    47201
# 10349    2024-08  WEEKENDS/HOLIDAY            9.0     BUS    47201
#
#        TOTAL_TAP_IN_VOLUME  TOTAL_TAP_OUT_VOLUME
# 4584                   670                  1115
# 7187                   917                  1212
# 8878                  7761                 11219
# 9256                   126                    11
# 10349                  803                  1647

# %%
woodlands_bus_stops = [47201, 46631, 46639, 46641, 46649, 46331, 46339, 46321, 46329, 46989, 46981, 46991, 46999, 47749]
pv_bus_woodlands = pv_bus[pv_bus['PT_CODE'].isin(woodlands_bus_stops)]
print(pv_bus_woodlands.head())

# Group by PT_CODE and YEAR_MONTH, and aggregate the tap-in and tap-out volumes
grouped_df = pv_bus_woodlands.groupby('YEAR_MONTH').agg({
    'TOTAL_TAP_IN_VOLUME': 'sum',
    'TOTAL_TAP_OUT_VOLUME': 'sum'
}).reset_index()

plt.plot(pt_code_df['YEAR_MONTH'], pt_code_df['TOTAL_TAP_IN_VOLUME'], label=f'Tap-ins')
plt.plot(pt_code_df['YEAR_MONTH'], pt_code_df['TOTAL_TAP_OUT_VOLUME'], label=f'Tap-outs', linestyle='--')

plt.xlabel('Year-Month')
plt.ylabel('Passenger Volume')
plt.title('Passenger Volume Trends - Woodlands MRT Vicinity')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %%
pv_bus_marpar = pv_bus[pv_bus['PT_CODE'].isin([92049, 92041, 92051, 92059])]
print(pv_bus_marpar.head())

# Group by PT_CODE and YEAR_MONTH, and aggregate the tap-in and tap-out volumes
grouped_df = pv_bus_marpar.groupby('YEAR_MONTH').agg({
    'TOTAL_TAP_IN_VOLUME': 'sum',
    'TOTAL_TAP_OUT_VOLUME': 'sum'
}).reset_index()

plt.plot(pt_code_df['YEAR_MONTH'], pt_code_df['TOTAL_TAP_IN_VOLUME'], label=f'Tap-ins')
plt.plot(pt_code_df['YEAR_MONTH'], pt_code_df['TOTAL_TAP_OUT_VOLUME'], label=f'Tap-outs', linestyle='--')

plt.xlabel('Year-Month')
plt.ylabel('Passenger Volume')
plt.title('Passenger Volume Trends - Marine Parade MRT Vicinity')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#      YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  PT_CODE  \
# 1967    2024-08           WEEKDAY           17.0     BUS    92041
# 2018    2024-08  WEEKENDS/HOLIDAY           11.0     BUS    92041
# 2281    2024-08           WEEKDAY           16.0     BUS    92041
# 2989    2024-08  WEEKENDS/HOLIDAY           11.0     BUS    92059
# 8501    2024-08  WEEKENDS/HOLIDAY           12.0     BUS    92059
#
#       TOTAL_TAP_IN_VOLUME  TOTAL_TAP_OUT_VOLUME
# 1967                 5927                  7198
# 2018                 1564                  4215
# 2281                 4296                  6503
# 2989                  751                   882
# 8501                  767                   751

# %% [markdown]
# #### Passenger Volume by Origin Destination Bus Stops

# %%
# PASSENGER VOLUME BY ORIGIN DESTINATION BUS STOPS DATA DOWNLOAD LINK

def call_pv_od_bus_api(date):
  url = "https://datamall2.mytransport.sg/ltaodataservice/PV/ODBus?Date=" + date

  payload = {}
  headers = {
    'AccountKey': '',
    'Accept': 'application/json'
  }

  response = requests.request("GET", url, headers=headers, data=payload)

  return response.json()

call_pv_od_bus_api('202408')

# %%
# List of CSV file paths
pv_od_bus_csv_files = ['dsa4264-lta-geospatial/data/origin_destination_bus_202407.csv', 'dsa4264-lta-geospatial/data/origin_destination_bus_202406.csv', 'dsa4264-lta-geospatial/data/origin_destination_bus_202408.csv']

# Read and combine all CSVs into one DataFrame
df_list = [pd.read_csv(file) for file in pv_od_bus_csv_files]
pv_od_bus = pd.concat(df_list, ignore_index=True)

pv_od_bus.head()
# Out:
#   YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  ORIGIN_PT_CODE  \
# 0    2024-07           WEEKDAY             22     BUS           43499
# 1    2024-07  WEEKENDS/HOLIDAY             23     BUS           22009
# 2    2024-07           WEEKDAY             22     BUS           10099
# 3    2024-07  WEEKENDS/HOLIDAY             16     BUS            7419
# 4    2024-07           WEEKDAY              9     BUS           72079
#
#    DESTINATION_PT_CODE  TOTAL_TRIPS
# 0                43481            1
# 1                14109            1
# 2                 3031            1
# 3                 7031           33
# 4                60089            4

# %%
pv_od_bus_woodlands = pv_od_bus[(pv_od_bus['ORIGIN_PT_CODE'].isin(woodlands_bus_stops)) | (pv_od_bus['DESTINATION_PT_CODE'].isin(woodlands_bus_stops))]
#pv_od_bus_marpar = pv_od_bus[(pv_od_bus['ORIGIN_PT_CODE'].isin([92049, 92041, 92051, 92059])) | (pv_od_bus['DESTINATION_PT_CODE'].isin([92049, 92041, 92051, 92059]))]

print(pv_od_bus_woodlands.head())

# Group by YEAR_MONTH and sum the TOTAL_PASSENGER_VOLUME
grouped_df = pv_od_bus_woodlands.groupby(['YEAR_MONTH', 'DAY_TYPE']).agg({
    'TOTAL_TRIPS': 'sum'
}).reset_index()

# Plot the trend for each DAY_TYPE
for day_type in grouped_df['DAY_TYPE'].unique():
    day_type_df = grouped_df[grouped_df['DAY_TYPE'] == day_type]
    
    # Plotting
    plt.plot(pt_code_df['YEAR_MONTH'], pt_code_df['TOTAL_TRIPS'], label=f'Total trips {day_type}')
    plt.plot(pt_code_df['YEAR_MONTH'], pt_code_df['TOTAL_TRIPS'], label=f'Total Trips {day_type}', linestyle='--')

plt.xlabel('Year-Month')
plt.ylabel('Total Trips')
plt.title('Woodlands MRT Vicinity Total Trips Trend')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#      YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  ORIGIN_PT_CODE  \
# 252     2024-07           WEEKDAY             18     BUS           46329
# 271     2024-07  WEEKENDS/HOLIDAY             15     BUS           47569
# 453     2024-07           WEEKDAY             16     BUS           46321
# 1490    2024-07           WEEKDAY              6     BUS           46321
# 1983    2024-07           WEEKDAY              7     BUS           75361
#
#       DESTINATION_PT_CODE  TOTAL_TRIPS
# 252                 46641            3
# 271                 46639            5
# 453                 46069           19
# 1490                46331           18
# 1983                46639            3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/DSA4264/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TOTAL_TRIPS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 16
#      13     day_type_df = grouped_df[grouped_df['DAY_TYPE'] == day_type]
#      15     # Plotting
# ---> 16     plt.plot(pt_code_df['YEAR_MONTH'], pt_code_df['TOTAL_TRIPS'], label=f'Total trips {day_type}')
#      17     plt.plot(pt_code_df['YEAR_MONTH'], pt_code_df['TOTAL_TRIPS'], label=f'Total Trips {day_type}', linestyle='--')
#      19 plt.xlabel('Year-Month')
#
# File ~/Desktop/DSA4264/.venv/lib/python3.9/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Desktop/DSA4264/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'TOTAL_TRIPS'
